# %%
import pickle
import pprint
import glob
import pandas as pd
import seaborn as sns
pp = pprint.PrettyPrinter(depth=6)
pd.set_option('max_colwidth',400)
pd.set_option('max_rows',200)

# %%
csv_folder = "../csv"
pkl_folder = "../pkl"

# %% [markdown]
# Downloaded 0 comparisons...
# Comparing 2.10 and 2.10.1...
# Comparing 2.10.1 and 2.11...
# Comparing 2.11 and 2.12...
# Comparing 2.12 and 2.13...
# Comparing 2.13 and 2.13.1...
# Comparing 2.13.1 and 2.14...
# Comparing 2.14 and 2.6...
# Comparing 2.6 and 2.7...
# Comparing 2.7 and 2.8...
# Comparing 2.8 and 2.9...
# Comparing 2.9 and 3.0...
# Comparing 3.0 and 3.0.1...
# Comparing 3.0.1 and 3.1...
# Comparing 3.1 and 3.1.1...
# Comparing 3.1.1 and 3.2...
# Comparing 3.2 and 3.2.1...
# Comparing 3.2.1 and 3.3...
# Comparing 3.3 and 3.3.1...
# Comparing 3.3.1 and 3.3.2...
# Comparing 3.3.2 and 3.4...
# Comparing 3.4 and 3.4.1...
# Comparing 3.4.1 and 3.5...
# Comparing 3.5 and 3.5.1...
# Comparing 3.5.1 and 3.6...
# Comparing 3.6 and 3.6.1...
# Comparing 3.6.1 and 3.6.2...
# Comparing 3.6.2 and 3.6.3...
# Comparing 3.6.3 and 3.7...
# Comparing 3.7 and 3.7.1-RC1-...
# Comparing 3.7.1-RC1- and 3.7.1...
# Comparing 3.7.1 and 3.7.2...
# Comparing 3.7.2 and 3.7.4...
# Comparing 3.7.4 and 4.0...
# Comparing 4.0 and 4.1-RC1...
# Comparing 4.1-RC1 and 4.1-RC2...
# Comparing 4.1-RC2 and 4.1...
# Comparing 4.1 and 4.1.1...
# Comparing 4.1.1 and 4.1.2...
# Comparing 4.1.2 and 4.2...
# Comparing 4.2 and 4.3...
# Comparing 4.3 and 4.3.1...
# Comparing 4.3.1 and 4.3.2...
# Comparing 4.3.2 and 4.3.3...
# Comparing 4.3.3 and 4.4-RC1...
# Comparing 4.4-RC1 and 4.4-RC2...
# Comparing 4.4-RC2 and 4.4-RC3...
# Comparing 4.4-RC3 and 4.4...
# Comparing 4.4 and 4.4.1...
# Comparing 4.4.1 and 4.5-RC1...
# Comparing 4.5-RC1 and 4.5-RC2...
# Downloaded 50 comparisons...
# Comparing 4.5-RC2 and 4.5-RC3...
# Comparing 4.5-RC3 and 4.5...
# Comparing 4.5 and 4.5.1-RC1...
# Comparing 4.5.1-RC1 and 4.5.1...
# Comparing 4.5.1 and 4.5.2...
# Comparing 4.5.2 and 4.5.3...
# Comparing 4.5.3 and 4.5.4...
# Comparing 4.5.4 and 4.5.5...
# Comparing 4.5.5 and 4.5.6...
# Comparing 4.5.6 and 4.5.7...
# Comparing 4.5.7 and 5.0-RC1...
# Comparing 5.0-RC1 and 5.0-RC2...
# Comparing 5.0-RC2 and 5.0-RC3...
# Comparing 5.0-RC3 and 5.0-RC4...
# Comparing 5.0-RC4 and 5.0...
# Comparing 5.0 and 5.0.1...
# Comparing 5.0.1 and 5.1-RC1...
# Comparing 5.1-RC1 and 5.1-RC2...
# Comparing 5.1-RC2 and 5.1...
# Comparing 5.1 and 5.1.1...
# Comparing 5.1.1 and 5.1.2...
# Comparing 5.1.2 and 5.2-RC1...
# Comparing 5.2-RC1 and 5.2-RC2...
# Comparing 5.2-RC2 and 5.2-RC3...
# Comparing 5.2-RC3 and 5.2...
# Comparing 5.2 and 5.3-RC1...
# Comparing 5.3-RC1 and 5.3-RC2...
# Comparing 5.3-RC2 and 5.3-RC3...
# Comparing 5.3-RC3 and 5.3...
# Comparing 5.3 and 5.4-M2...
# Comparing 5.4-M2 and 5.4-M3...
# Comparing 5.4-M3 and 5.4-M4...
# Comparing 5.4-M4 and 5.4-M5...
# Comparing 5.4-M5 and 5.4-M7...
# Comparing 5.4-M7 and 5.4-M6...
# Comparing 5.4-M6 and 5.4-M8...
# Comparing 5.4-M8 and 5.4-M9...
# Comparing 5.4-M9 and 5.4-M10...
# Comparing 5.4-M10 and 5.4-M11...
# Comparing 5.4-M11 and 5.4-M12...
# Comparing 5.4-M12 and 5.4-M13...
# Comparing 5.4-M13 and 5.4-RC1...
# Comparing 5.4-RC1 and 5.4-M14...
# Comparing 5.4-M14 and 5.4-M1...
# Comparing 5.4-M1 and 5.4-RC2...
# Comparing 5.4-RC2 and 5.4-RC3...
# Comparing 5.4-RC3 and 5.4-RC4...
# Comparing 5.4-RC4 and 5.4...
# Comparing 5.4 and 5.5-M1...
# Comparing 5.5-M1 and 5.5-M2...
# Downloaded 100 comparisons...
# Comparing 5.5-M2 and 5.5-M3...
# Comparing 5.5-M3 and 5.5-M4...
# Comparing 5.5-M4 and 5.5-M5...
# Comparing 5.5-M5 and 5.5-M6...
# Comparing 5.5-M6 and 5.5-M7...
# Comparing 5.5-M7 and 5.5-M10...
# Comparing 5.5-M10 and 5.5-M11...
# Comparing 5.5-M11 and 5.5-M12...
# Comparing 5.5-M12 and 5.5-M13...
# Comparing 5.5-M13 and 5.5-M14...
# Comparing 5.5-M14 and 5.5-RC1...
# Comparing 5.5-RC1 and 5.5-RC2...
# Comparing 5.5-RC2 and 5.5...
# Comparing 5.5 and 5.6-RC1...
# Comparing 5.6-RC1 and 5.6-RC2...
# Comparing 5.6-RC2 and 5.6...
# Comparing 5.6 and 5.6.1...
# Comparing 5.6.1 and 5.6.2...
# Comparing 5.6.2 and 5.6.3...
# Comparing 5.6.3 and 5.6.4...
# Comparing 5.6.4 and 5.6.5...
# Comparing 5.6.5 and 5.6.6...
# Comparing 5.6.6 and 5.6.7...
# Comparing 5.6.7 and 6.0-RC1...
# Comparing 6.0-RC1 and 6.0-RC2...
# Comparing 6.0-RC2 and 6.0...
# Comparing 6.0 and 6.1-RC1...
# Comparing 6.1-RC1 and 6.1-RC2...
# Comparing 6.1-RC2 and 6.1...
# Comparing 6.1 and 6.1.1...
# Comparing 6.1.1 and 6.2-RC1...
# Comparing 6.2-RC1 and 6.2-RC2...
# Comparing 6.2-RC2 and 6.2-RC3...
# Comparing 6.2-RC3 and 6.2...
# Comparing 6.2 and 6.2.1...
# Comparing 6.2.1 and 6.3-RC1...
# Comparing 6.3-RC1 and 6.3-RC4...
# Comparing 6.3-RC4 and 6.3...
# Comparing 6.3 and 6.3.0.18401...
# Comparing 6.3.0.18401 and 6.3.0.18587...
# Comparing 6.3.0.18587 and 6.3.0.18800...
# Comparing 6.3.0.18800 and 6.3.1...
# Comparing 6.3.1 and 6.3.2...
# Comparing 6.3.2 and 6.4-RC1...
# Comparing 6.4-RC1 and 6.4-RC2...
# Comparing 6.4-RC2 and 6.4-RC3...
# Comparing 6.4-RC3 and 6.4...
# Comparing 6.4 and 6.5-M1...
# Comparing 6.5-M1 and 6.5-M2...
# Comparing 6.5-M2 and 6.5-RC1...
# Downloaded 150 comparisons...
# Comparing 6.5-RC1 and 6.5-M3...
# Comparing 6.5-M3 and 6.5-RC2...
# Comparing 6.5-RC2 and 6.5-M4...
# Comparing 6.5-M4 and 6.5...
# Comparing 6.5 and 6.6-RC1...
# Comparing 6.6-RC1 and 6.6...
# Comparing 6.6 and 6.7-RC1...
# Comparing 6.7-RC1 and 6.7...
# Comparing 6.7 and 6.7.1...
# Comparing 6.7.1 and 6.7.2...
# Comparing 6.7.2 and 6.7.3...
# Comparing 6.7.3 and 6.7.4...
# Comparing 6.7.4 and 6.7.5...
# Comparing 6.7.5 and 6.7.6...
# Comparing 6.7.6 and 6.7.7...
# Comparing 6.7.7 and 7.0-RC1...
# Comparing 7.0-RC1 and 7.0...
# Comparing 7.0 and 7.5...
# Comparing 7.5 and 7.6...
# Comparing 7.6 and 7.7...
# Comparing 7.7 and 7.8...
# Comparing 7.8 and 7.9...
# Comparing 7.9 and 7.9.1...
# Comparing 7.9.1 and 7.9.2...
# Comparing 7.9.2 and 7.9.3...
# Comparing 7.9.3 and 7.9.4...
# Comparing 7.9.4 and 8.0...
# Comparing 8.0 and 8.1.0.31237...
# Comparing 8.1.0.31237 and 8.2.0.32929...
# Comparing 8.2.0.32929 and 8.3.0.34182...
# Comparing 8.3.0.34182 and 8.3.1.34397...
# Comparing 8.3.1.34397 and 8.4.0.35506...
# Comparing 8.4.0.35506 and 8.4.1.35646...
# Comparing 8.4.1.35646 and 8.4.2.36762...
# Comparing 8.4.2.36762 and latest-silver-master-#65...

# %% [markdown]
# ### Import df

# %%
jobsDf = pd.read_csv(f"{csv_folder}/allJobs.csv", index_col=0)

# %%
tagsDf = pd.read_csv(f"{csv_folder}/tags.csv", index_col=0)

# %% [markdown]
# ### Import tag comparisons

# %%
comp_files = glob.glob(f"{pkl_folder}/compare_tags/*.pkl")
comp_raw = []
for comp_file in comp_files:
    with open(comp_file, "rb") as f:
        comp_raw = comp_raw + pickle.load(f)

# %%
pp.pprint(comp_raw[0])
# Out:
# {'ahead_by': 1,
#  'base_commit': {'author': {'avatar_url': 'https://avatars1.githubusercontent.com/u/112486?v=4',
#                             'events_url': 'https://api.github.com/users/ehartmann/events{/privacy}',
#                             'followers_url': 'https://api.github.com/users/ehartmann/followers',
#                             'following_url': 'https://api.github.com/users/ehartmann/following{/other_user}',
#                             'gists_url': 'https://api.github.com/users/ehartmann/gists{/gist_id}',
#                             'gravatar_id': '',
#                             'html_url': 'https://github.com/ehartmann',
#                             'id': 112486,
#                             'login': 'ehartmann',
#                             'node_id': 'MDQ6VXNlcjExMjQ4Ng==',
#                             'organizations_url': 'https://api.github.com/users/ehartmann/orgs',
#                             'received_events_url': 'https://api.github.com/users/ehartmann/received_events',
#                             'repos_url': 'https://api.github.com/users/ehartmann/repos',
#                             'site_admin': False,
#                             'starred_url': 'https://api.github.com/users/ehartmann/starred{/owner}{/repo}',
#                             'subscriptions_url': 'https://api.github.com/users/ehartmann/subscriptions',
#                             'type': 'User',
#                             'url': 'https://api.github.com/users/ehartmann'},
#                  'comments_url': 'https://api.github.com/repos/SonarSource/sonarqube/commits/ce5229098c88b7da25be2955695d5c18f9fc1445/comments',
#                  'commit': {'author': {'date': '2011-11-28T08:42:38Z',
#                                        'email': 'hartmann.eric@gmail.com',
#                                        'name': 'Eric Hartmann'},
#                             'comment_count': 0,
#                             'committer': {'date': '2011-11-28T08:42:38Z',
#                                           'email': 'hartmann.eric@gmail.com',
#                                           'name': 'Eric Hartmann'},
#                             'message': 'Release 2.12',
#                             'tree': {'sha': 'f8c96da47708f3f51d251057d5b6596c46aadbab',
#                                      'url': 'https://api.github.com/repos/SonarSource/sonarqube/git/trees/f8c96da47708f3f51d251057d5b6596c46aadbab'},
#                             'url': 'https://api.github.com/repos/SonarSource/sonarqube/git/commits/ce5229098c88b7da25be2955695d5c18f9fc1445',
#                             'verification': {'payload': None,
#                                              'reason': 'unsigned',
#                                              'signature': None,
#                                              'verified': False}},
#                  'committer': {'avatar_url': 'https://avatars1.githubusercontent.com/u/112486?v=4',
#                                'events_url': 'https://api.github.com/users/ehartmann/events{/privacy}',
#                                'followers_url': 'https://api.github.com/users/ehartmann/followers',
#                                'following_url': 'https://api.github.com/users/ehartmann/following{/other_user}',
#                                'gists_url': 'https://api.github.com/users/ehartmann/gists{/gist_id}',
#                                'gravatar_id': '',
#                                'html_url': 'https://github.com/ehartmann',
#                                'id': 112486,
#                                'login': 'ehartmann',
#                                'node_id': 'MDQ6VXNlcjExMjQ4Ng==',
#                                'organizations_url': 'https://api.github.com/users/ehartmann/orgs',
#                                'received_events_url': 'https://api.github.com/users/ehartmann/received_events',
#                                'repos_url': 'https://api.github.com/users/ehartmann/repos',
#                                'site_admin': False,
#                                'starred_url': 'https://api.github.com/users/ehartmann/starred{/owner}{/repo}',
#                                'subscriptions_url': 'https://api.github.com/users/ehartmann/subscriptions',
#                                'type': 'User',
#                                'url': 'https://api.github.com/users/ehartmann'},
#                  'html_url': 'https://github.com/SonarSource/sonarqube/commit/ce5229098c88b7da25be2955695d5c18f9fc1445',
#                  'node_id': 'MDY6Q29tbWl0MTIyMjUwNDpjZTUyMjkwOThjODhiN2RhMjViZTI5NTU2OTVkNWMxOGY5ZmMxNDQ1',
#                  'parents': [{'html_url': 'https://github.com/SonarSource/sonarqube/commit/973e82a2c8b7f2d083a996d0c920cbfacd37c35e',
#                               'sha': '973e82a2c8b7f2d083a996d0c920cbfacd37c35e',
#                               'url': 'https://api.github.com/repos/SonarSource/sonarqube/commits/973e82a2c8b7f2d083a996d0c920cbfacd37c35e'}],
#                  'sha': 'ce5229098c88b7da25be2955695d5c18f9fc1445',
#                  'url': 'https://api.github.com/repos/SonarSource/sonarqube/commits/ce5229098c88b7da25be2955695d5c18f9fc1445'},
#  'behind_by': 445,
#  'commits': [],
#  'diff_url': 'https://github.com/SonarSource/sonarqube/compare/2.12...2.10.diff',
#  'files': [{'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/archetypes/sonar-basic-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/archetypes/sonar-basic-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'archetypes/sonar-basic-plugin/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      ' ',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/archetypes/sonar-basic-plugin/pom.xml',
#             'sha': '861c88b6ef1a13f940e1c7c147f98590ae2277af',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/archetypes/sonar-gwt-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/archetypes/sonar-gwt-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'archetypes/sonar-gwt-plugin/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      ' ',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/archetypes/sonar-gwt-plugin/pom.xml',
#             'sha': '4f53f80dc52abb5552c998ece12a1aa03f726713',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-checkstyle-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-checkstyle-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-checkstyle-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-checkstyle-plugin/pom.xml',
#             'sha': '98a1d6d1a2b89c9cdee53a39a0c5f866c598bf10',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-cobertura-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-cobertura-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-cobertura-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-cobertura-plugin/pom.xml',
#             'sha': '80ec7f34ff2212f305e0c093c7c01be1d50baeba',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-core-gwt/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-core-gwt/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-core-gwt/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-core-gwt</artifactId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-core-gwt/pom.xml',
#             'sha': '6ca87684f3ecc9509be7fe767d8f85fe7fbef746',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-core-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-core-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-core-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-core-plugin/pom.xml',
#             'sha': 'ad47309db53486cafe4ca7b62f134162f71d27c7',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-cpd-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-cpd-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-cpd-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-cpd-plugin/pom.xml',
#             'sha': 'f1859005cce10621fc98a06766b34de67a520229',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-dbcleaner-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-dbcleaner-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-dbcleaner-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-dbcleaner-plugin/pom.xml',
#             'sha': '20f617faefeea729e334159dadeba113c50db794',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-design-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-design-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-design-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-design-plugin/pom.xml',
#             'sha': 'f9bc82316d08cdbe0eb5320b42d1c74047ab5b5f',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-email-notifications-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-email-notifications-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-email-notifications-plugin/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      ' ',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-email-notifications-plugin/pom.xml',
#             'sha': 'e329229436b513a915c0c87dc0d6e0dbb3c6439d',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-findbugs-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-findbugs-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-findbugs-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-findbugs-plugin/pom.xml',
#             'sha': '2d85751974f8f050c1e4c018bb611889705592b3',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-googleanalytics-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-googleanalytics-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-googleanalytics-plugin/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      ' ',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-googleanalytics-plugin/pom.xml',
#             'sha': 'd48b1f1f1e7dd1c0a3651c91b5a0ff4c70b20970',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-l10n-en-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-l10n-en-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-l10n-en-plugin/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      ' ',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-l10n-en-plugin/pom.xml',
#             'sha': 'b8726715aeba46607db8399f3094893f3582af38',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-pmd-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-pmd-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-pmd-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-pmd-plugin/pom.xml',
#             'sha': '485de007e6276e034a098b56a15c0b2145f07fff',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-squid-java-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-squid-java-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-squid-java-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.plugins</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-squid-java-plugin/pom.xml',
#             'sha': '199b2215f1940553826812044aaff2529f7a5d9b',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-surefire-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/plugins/sonar-surefire-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'plugins/sonar-surefire-plugin/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>../..</relativePath>\n'
#                      '   </parent>\n'
#                      ' ',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/plugins/sonar-surefire-plugin/pom.xml',
#             'sha': '1c32201118e296136e022f98aa7c0636eae073d2',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <groupId>org.codehaus.sonar</groupId>\n'
#                      '   <artifactId>sonar</artifactId>\n'
#                      '   <packaging>pom</packaging>\n'
#                      '-  <version>2.10-SNAPSHOT</version>\n'
#                      '+  <version>2.10</version>\n'
#                      '   <name>Sonar</name>\n'
#                      '   <url>http://www.sonarsource.org</url>\n'
#                      '   <description>Put technical debt under '
#                      'control</description>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/pom.xml',
#             'sha': '23545d33c7eb7b4c2a40e9920d3a89bc8705d583',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/samples/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/samples/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'samples/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar.samples</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/samples/pom.xml',
#             'sha': '082a6eefcb3cff28d1a4a2dea21b599a141a757a',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-application/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-application/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-application/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-application</artifactId>\n'
#                      '   <packaging>jar</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-application/pom.xml',
#             'sha': '2b0f67d9c24a9326f2f24a3c1ccb5f13ecdbc116',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-batch-bootstrapper/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-batch-bootstrapper/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-batch-bootstrapper/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      ' \n'
#                      '   <artifactId>sonar-batch-bootstrapper</artifactId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-batch-bootstrapper/pom.xml',
#             'sha': '329778c5137ed0a3d1dda8dca00eda66de7f8096',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-batch-maven-compat/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-batch-maven-compat/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-batch-maven-compat/pom.xml',
#             'patch': '@@ -5,7 +5,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      ' \n'
#                      '   <artifactId>sonar-batch-maven-compat</artifactId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-batch-maven-compat/pom.xml',
#             'sha': '32a799e6b14a7b6c0ba0f07124018c71eda69182',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-batch/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-batch/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-batch/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      ' \n'
#                      '   <groupId>org.codehaus.sonar</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-batch/pom.xml',
#             'sha': 'fe8783f70904b32238c1ff811c8bf2ea607ea4fb',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-channel/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-channel/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-channel/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      ' \t<parent>\n'
#                      ' \t\t<groupId>org.codehaus.sonar</groupId>\n'
#                      ' \t\t<artifactId>sonar</artifactId>\n'
#                      '-\t\t<version>2.10-SNAPSHOT</version>\n'
#                      '+\t\t<version>2.10</version>\n'
#                      ' \t\t<relativePath>..</relativePath>\n'
#                      ' \t</parent>\n'
#                      ' \t<artifactId>sonar-channel</artifactId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-channel/pom.xml',
#             'sha': '0b60f711c6029b563649be1bfbdb1987fc98c03f',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-check-api/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-check-api/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-check-api/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-check-api</artifactId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-check-api/pom.xml',
#             'sha': 'a9897d981ff96dd18e6de1cc1e3fbc969e250faf',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-colorizer/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-colorizer/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-colorizer/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-colorizer</artifactId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-colorizer/pom.xml',
#             'sha': '37dc07f6e6233f6fc55269e1d06657dc9349dee8',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-core-maven-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-core-maven-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-core-maven-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      ' \n'
#                      "   <!-- do not change, it's used when deploying in sonar "
#                      'internal repository -->',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-core-maven-plugin/pom.xml',
#             'sha': '0f57ad7c56ccb7572b68c58295fd81f228e844ac',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-core/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-core/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-core/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-core</artifactId>\n'
#                      '   <name>Sonar :: Core</name>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-core/pom.xml',
#             'sha': '0a0bf6015ef936d48bacba0ac83f38d92ecab21b',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-deprecated/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-deprecated/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-deprecated/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-deprecated</artifactId>\n'
#                      '   <name>Sonar :: Deprecated</name>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-deprecated/pom.xml',
#             'sha': '9d5bb7c60547e8a33bc4ef5675f293efc4093b5d',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-duplications/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-duplications/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-duplications/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-duplications</artifactId>\n'
#                      '   <name>Sonar :: Duplications</name>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-duplications/pom.xml',
#             'sha': '97ad63d592985949cefec70ece72c353e81737ca',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-graph/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-graph/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-graph/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-graph/pom.xml',
#             'sha': '91ff5e05a4ef09c4611559d51e92bcfbe44cb9ab',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-gwt-api/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-gwt-api/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-gwt-api/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-gwt-api</artifactId>\n'
#                      '   <packaging>jar</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-gwt-api/pom.xml',
#             'sha': 'da3189a4b20a648cb0a4a5e75a87e790e7412fbb',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-java-api/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-java-api/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-java-api/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-java-api</artifactId>\n'
#                      '   <name>Sonar :: Java API</name>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-java-api/pom.xml',
#             'sha': 'da054bc44d024bed9dfcc168dac2e53374f03442',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-markdown/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-markdown/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-markdown/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      ' \t<parent>\n'
#                      ' \t\t<groupId>org.codehaus.sonar</groupId>\n'
#                      ' \t\t<artifactId>sonar</artifactId>\n'
#                      '-\t\t<version>2.10-SNAPSHOT</version>\n'
#                      '+\t\t<version>2.10</version>\n'
#                      ' \t\t<relativePath>..</relativePath>\n'
#                      ' \t</parent>\n'
#                      ' \t<artifactId>sonar-markdown</artifactId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-markdown/pom.xml',
#             'sha': '1c2c73651649b75a94ad026c532a6b7f0b758169',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-maven-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-maven-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-maven-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-maven-plugin</artifactId>\n'
#                      '   <packaging>maven-plugin</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-maven-plugin/pom.xml',
#             'sha': '989f7724b49bb46e87068b83600d761c186baee5',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-maven3-plugin/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-maven3-plugin/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-maven3-plugin/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-maven3-plugin</artifactId>\n'
#                      '   <packaging>maven-plugin</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-maven3-plugin/pom.xml',
#             'sha': 'd38681c003bb94667ec7bb516baf60c6c6f09a6f',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-plugin-api/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-plugin-api/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-plugin-api/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-plugin-api</artifactId>\n'
#                      '   <packaging>jar</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-plugin-api/pom.xml',
#             'sha': '56138784bf14f7f36b9af3311e4eea0a3efb542b',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-server/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-server/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-server/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-server</artifactId>\n'
#                      '   <packaging>war</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-server/pom.xml',
#             'sha': '3cdb4a9358d93b2146cfcb7d6dd7bc86bea3fbe0',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-squid/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-squid/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-squid/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '     <relativePath>..</relativePath>\n'
#                      '   </parent>\n'
#                      '   <groupId>org.codehaus.sonar</groupId>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-squid/pom.xml',
#             'sha': '6234feb7b879df3c3c954c93e398dc0c9a921272',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-testing-harness/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-testing-harness/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-testing-harness/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-testing-harness</artifactId>\n'
#                      '   <packaging>jar</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-testing-harness/pom.xml',
#             'sha': '7ae76e7de01d2641a19709e2e10fcfd5d4908ad5',
#             'status': 'modified'},
#            {'additions': 1,
#             'blob_url': 'https://github.com/SonarSource/sonarqube/blob/43f27118331e8395365562c3859986489e38fb0a/sonar-ws-client/pom.xml',
#             'changes': 2,
#             'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/sonar-ws-client/pom.xml?ref=43f27118331e8395365562c3859986489e38fb0a',
#             'deletions': 1,
#             'filename': 'sonar-ws-client/pom.xml',
#             'patch': '@@ -4,7 +4,7 @@\n'
#                      '   <parent>\n'
#                      '     <groupId>org.codehaus.sonar</groupId>\n'
#                      '     <artifactId>sonar</artifactId>\n'
#                      '-    <version>2.10-SNAPSHOT</version>\n'
#                      '+    <version>2.10</version>\n'
#                      '   </parent>\n'
#                      '   <artifactId>sonar-ws-client</artifactId>\n'
#                      '   <packaging>jar</packaging>',
#             'raw_url': 'https://github.com/SonarSource/sonarqube/raw/43f27118331e8395365562c3859986489e38fb0a/sonar-ws-client/pom.xml',
#             'sha': '23b1395db3a3794c5b7ade61f060261d314fefd6',
#             'status': 'modified'}],
#  'html_url': 'https://github.com/SonarSource/sonarqube/compare/2.12...2.10',
#  'merge_base_commit': {'author': None,
#                        'comments_url': 'https://api.github.com/repos/SonarSource/sonarqube/commits/6b0cc08317c9e2901af91542c0177182eaaf8c38/comments',
#                        'commit': {'author': {'date': '2011-08-18T09:13:14Z',
#                                              'email': 'simon.brandhof@gmail.com',
#                                              'name': 'Simon Brandhof'},
#                                   'comment_count': 0,
#                                   'committer': {'date': '2011-08-18T09:13:14Z',
#                                                 'email': 'simon.brandhof@gmail.com',
#                                                 'name': 'Simon Brandhof'},
#                                   'message': 'SONAR-75 implement negative '
#                                              'cache of rule descriptions',
#                                   'tree': {'sha': '6b36b1b6da8c6547ec0814a268a9a670285a5e3e',
#                                            'url': 'https://api.github.com/repos/SonarSource/sonarqube/git/trees/6b36b1b6da8c6547ec0814a268a9a670285a5e3e'},
#                                   'url': 'https://api.github.com/repos/SonarSource/sonarqube/git/commits/6b0cc08317c9e2901af91542c0177182eaaf8c38',
#                                   'verification': {'payload': None,
#                                                    'reason': 'unsigned',
#                                                    'signature': None,
#                                                    'verified': False}},
#                        'committer': None,
#                        'html_url': 'https://github.com/SonarSource/sonarqube/commit/6b0cc08317c9e2901af91542c0177182eaaf8c38',
#                        'node_id': 'MDY6Q29tbWl0MTIyMjUwNDo2YjBjYzA4MzE3YzllMjkwMWFmOTE1NDJjMDE3NzE4MmVhYWY4YzM4',
#                        'parents': [{'html_url': 'https://github.com/SonarSource/sonarqube/commit/17aeea97bd1a04f84d6ed0b2f532d5597d300ca1',
#                                     'sha': '17aeea97bd1a04f84d6ed0b2f532d5597d300ca1',
#                                     'url': 'https://api.github.com/repos/SonarSource/sonarqube/commits/17aeea97bd1a04f84d6ed0b2f532d5597d300ca1'}],
#                        'sha': '6b0cc08317c9e2901af91542c0177182eaaf8c38',
#                        'url': 'https://api.github.com/repos/SonarSource/sonarqube/commits/6b0cc08317c9e2901af91542c0177182eaaf8c38'},
#  'patch_url': 'https://github.com/SonarSource/sonarqube/compare/2.12...2.10.patch',
#  'permalink_url': 'https://github.com/SonarSource/sonarqube/compare/SonarSource:ce52290...SonarSource:43f2711',
#  'status': 'diverged',
#  'total_commits': 1,
#  'url': 'https://api.github.com/repos/SonarSource/sonarqube/compare/2.12...2.10'}

# %%
len(comp_raw)
# Out:
# 99

# %%
comp_combination_data = []
for comp in comp_raw:
    if not "url" in comp:
        continue
    from_tag = comp["url"].split("...")[0].split("/")[-1]
    to_tag = comp["url"].split("...")[1]
    comp_combination_data.append((from_tag, to_tag, comp["ahead_by"], comp["behind_by"]))

# %%
from_tag = comp_raw[0]["url"].split("...")[0].split("/")[-1]
to_tag = comp_raw[0]["url"].split("...")[1]

# %%
from_tag
# Out:
# '2.12'

# %%
to_tag
# Out:
# '2.10'

# %%
set(tagsDf.Tag.unique()) - set(comp_tags_df.from_tag.unique())
# Out:
# {'2.14',
#  '4.5.4',
#  '5.4-M14',
#  '5.4-M7',
#  '6.3',
#  '6.7',
#  '8.4.2.36762',
#  'latest-silver-master-#65'}

# %%
tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag_number == "5.4"]
# Out:
# <ipython-input-51-4f24e6523828>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag_number == "5.4"]
#          Tag                                       Sha                 Date  \
# 104   5.4-M2  d7ea0a8b14b8649144f7bfbff055f207d954d6c9  2015-12-28 12:01:19
# 103   5.4-M3  0fddc5fa4ea33882b60e072eee51f0e1ea585b4c  2016-01-06 09:52:46
# 102   5.4-M4  eaf7b87bb681e86ebef1778039de929c211b1f99  2016-01-12 10:43:56
# 101   5.4-M5  0ad061c6a5c6a0e1c84511b1a2eb7db2f6764e35  2016-01-14 07:41:56
# 99    5.4-M7  366217e521da38a4b17f7e6ada0f4d6612475580  2016-01-14 10:05:29
# 100   5.4-M6  868e4d9403268e0f17235e1993496e92cb8883be  2016-01-15 08:27:52
# 98    5.4-M8  162d76a0e6964f1d42069b42ce0362fedd151f75  2016-01-18 08:43:40
# 97    5.4-M9  ed6f219718bdc9c6435e0cd32e4aa81d558fc302  2016-01-21 08:29:19
# 96   5.4-M10  bea2847df13b73c7364193419873e3e8b47b5b73  2016-01-28 16:10:59
# 95   5.4-M11  84d4f441879de01734bb9041fc0cdfbd461386ee  2016-02-01 14:45:36
# 94   5.4-M12  ca8c711145a11e61a3c6571cef38cf8d53b5d423  2016-02-03 12:52:05
# 93   5.4-M13  27858608f46ae9f1cd2c2269151e68f56f882417  2016-02-05 10:17:45
# 91   5.4-RC1  6bb02b28a33282bda2b9ed6bc995a4aee68ff172  2016-02-09 11:54:50
# 92   5.4-M14  df6129a0913277db1ec8f8ac4b9cc0303b8c9c25  2016-02-11 09:49:41
# 105   5.4-M1  df6129a0913277db1ec8f8ac4b9cc0303b8c9c25  2016-02-11 09:49:41
# 90   5.4-RC2  e8f951d9f2a99975e31f82d97fce68f47e9242d3  2016-02-15 15:38:37
# 89   5.4-RC3  19310ef05676362f6b88be6d1edc22a12af372b4  2016-03-01 09:36:10
# 88   5.4-RC4  ca9cfe39623b1ae2fdab458348f1b92838b7f151  2016-03-04 16:25:47
# 87       5.4  7b02df9be3cd9448699b5857586e1c6e2b28c007  2016-03-08 15:48:19
#
#     Tag_number
# 104        5.4
# 103        5.4
# 102        5.4
# 101        5.4
# 99         5.4
# 100        5.4
# 98         5.4
# 97         5.4
# 96         5.4
# 95         5.4
# 94         5.4
# 93         5.4
# 91         5.4
# 92         5.4
# 105        5.4
# 90         5.4
# 89         5.4
# 88         5.4
# 87         5.4

# %%
tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag_number.str.contains("4.5")]
# Out:
# <ipython-input-55-2443f6808768>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag_number.str.contains("4.5")]
#            Tag                                       Sha                 Date  \
# 136    4.5-RC1  70a1850e5e29e7a06f43132cf0c4cea51744d0d0  2014-09-08 08:38:53
# 135    4.5-RC2  18ec6d32baf94a2cac8441b0c508debf644d1a19  2014-09-16 20:54:20
# 134    4.5-RC3  8be553ee31f63476eb96c2c307100b9004fdef1e  2014-09-26 12:41:26
# 133        4.5  c8bb686cbee8e1dce3312ef253db76e7c0e3c0c7  2014-09-29 13:59:33
# 132  4.5.1-RC1  33d7a6c21e6968cb73155a5e52593f3cde3c8bcc  2014-10-24 13:34:33
# 131      4.5.1  0c5e3bad51d43c05de47187d16831067bea16a3f  2014-10-29 09:34:32
# 130      4.5.2  28ee49d18fd328e46de45736ac350eabb043c90d  2015-01-07 08:52:38
# 129      4.5.3  87f5816d42fc0e0deffdd86b564910aa51cf266e  2015-02-24 10:14:23
# 128      4.5.4  eccfe672f5e585c39cc6a0b79122ad516fd61f3e  2015-02-26 10:10:48
# 127      4.5.5  cc8a9472c671598fb3158b51b15863448a477a50  2015-07-30 10:02:58
# 126      4.5.6  12d931e5a31e1692a428bbb34ba11cd63aebf998  2015-10-16 09:31:18
# 125      4.5.7  e2afb0bff1b8be759789d2c1bc9348de6f519f83  2016-04-08 13:44:39
#
#     Tag_number
# 136        4.5
# 135        4.5
# 134        4.5
# 133        4.5
# 132      4.5.1
# 131      4.5.1
# 130      4.5.2
# 129      4.5.3
# 128      4.5.4
# 127      4.5.5
# 126      4.5.6
# 125      4.5.7

# %%
tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag.str.contains("5.4-M")]
# Out:
# <ipython-input-57-4b5e071cf567>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag.str.contains("5.4-M")]
#          Tag                                       Sha                 Date  \
# 104   5.4-M2  d7ea0a8b14b8649144f7bfbff055f207d954d6c9  2015-12-28 12:01:19
# 103   5.4-M3  0fddc5fa4ea33882b60e072eee51f0e1ea585b4c  2016-01-06 09:52:46
# 102   5.4-M4  eaf7b87bb681e86ebef1778039de929c211b1f99  2016-01-12 10:43:56
# 101   5.4-M5  0ad061c6a5c6a0e1c84511b1a2eb7db2f6764e35  2016-01-14 07:41:56
# 99    5.4-M7  366217e521da38a4b17f7e6ada0f4d6612475580  2016-01-14 10:05:29
# 100   5.4-M6  868e4d9403268e0f17235e1993496e92cb8883be  2016-01-15 08:27:52
# 98    5.4-M8  162d76a0e6964f1d42069b42ce0362fedd151f75  2016-01-18 08:43:40
# 97    5.4-M9  ed6f219718bdc9c6435e0cd32e4aa81d558fc302  2016-01-21 08:29:19
# 96   5.4-M10  bea2847df13b73c7364193419873e3e8b47b5b73  2016-01-28 16:10:59
# 95   5.4-M11  84d4f441879de01734bb9041fc0cdfbd461386ee  2016-02-01 14:45:36
# 94   5.4-M12  ca8c711145a11e61a3c6571cef38cf8d53b5d423  2016-02-03 12:52:05
# 93   5.4-M13  27858608f46ae9f1cd2c2269151e68f56f882417  2016-02-05 10:17:45
# 92   5.4-M14  df6129a0913277db1ec8f8ac4b9cc0303b8c9c25  2016-02-11 09:49:41
# 105   5.4-M1  df6129a0913277db1ec8f8ac4b9cc0303b8c9c25  2016-02-11 09:49:41
#
#     Tag_number
# 104        5.4
# 103        5.4
# 102        5.4
# 101        5.4
# 99         5.4
# 100        5.4
# 98         5.4
# 97         5.4
# 96         5.4
# 95         5.4
# 94         5.4
# 93         5.4
# 92         5.4
# 105        5.4

# %%
tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag.str.contains("6.3")]
# Out:
# <ipython-input-58-000892455658>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tagsDf.sort_values(by=["Tag_number", "Date"])[tagsDf.Tag.str.contains("6.3")]
#              Tag                                       Sha  \
# 158        3.6.3  0b5ca33de7a6f39463cb91037fc9d2cd1f40977f
# 66         5.6.3  a68d912046cfbbe3f9d1493ab53414face1adae2
# 49       6.3-RC1  534fc279a64c7b836f39d476d15192999944b9eb
# 48       6.3-RC4  e23682d9e420ef59da282322ca9dc6e3fc59d75b
# 47           6.3  43ea4f4c43aa89d4c435017f86d0da254e115e6b
# 46   6.3.0.18401  534fc279a64c7b836f39d476d15192999944b9eb
# 45   6.3.0.18587  3b673b37f88fc38b84244bd541d20ee9ac510486
# 44   6.3.0.18800  7a8f38e05f2264d550c232cd89518abd1155870a
# 43         6.3.1  54be39f47d188340b14d4d9236bbf3d43b1db2ae
# 42         6.3.2  84ad17dd4e53eae1221d1af96fb45d8997f2e2fa
#
#                     Date   Tag_number
# 158  2013-08-13 09:59:57        3.6.3
# 66   2016-10-03 13:56:53        5.6.3
# 49   2017-02-14 11:06:25          6.3
# 48   2017-03-04 17:53:45          6.3
# 47   2017-03-14 09:12:39          6.3
# 46   2017-02-14 11:06:25  6.3.0.18401
# 45   2017-02-16 16:38:40  6.3.0.18587
# 44   2017-02-22 15:04:12  6.3.0.18800
# 43   2017-04-11 12:44:29        6.3.1
# 42   2017-04-24 08:51:14        6.3.2

# %% [markdown]
# {'2.14', -> tagged much later
#  '4.5.4', -> seems a github error. 4.5.5 points to a commit sha cc8 which is visible here (1) https://github.com/SonarSource/sonarqube/compare/4.5.4...4.5.6 but https://github.com/SonarSource/sonarqube/compare/4.5.4...4.5.5 compares the same sha and says they are identical. Solution Take list from (1) up to cc8a947
#  '5.4-M14', -> compared with 5.4.M1 but they have the same sha.
#  '5.4-M7', -> tag 5.4-M6 has been created the day after M7 but when compared with M7 and M8 it looks like the order is the intuitive M6->M7->M8
#  '6.3',
#  '6.7',
#  '8.4.2.36762',
#  'latest-silver-master-#65'}

# %% [markdown]
# with open(f"{pkl_folder}/compare_tags_combination.pkl", "rb") as f:
#         comp_raw = pickle.load(f)

# %%
comp_comb_tags_df = pd.DataFrame(comp_combination_data, columns=["from_tag", "to_tag", "ahead_by", "behind_by"])

# %%
grp = comp_comb_tags_df[comp_comb_tags_df.behind_by == 0].groupby("to_tag").idxmin()
comp_comb_tags_df.loc[grp.ahead_by]
# Out:
#    from_tag  to_tag  ahead_by  behind_by
# 6      2.10  2.10.1         3          0
# 16     2.10    2.11       180          0
# 12      2.6    2.12      1235          0
# 54     2.12    2.13       286          0
# 48     2.13  2.13.1         3          0
# 22     2.12    2.14       649          0
# 98      2.6     2.7       135          0
# 77      2.7     2.8       272          0
# 69      2.8     2.9       196          0
