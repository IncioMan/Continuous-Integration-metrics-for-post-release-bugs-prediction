# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from ast import literal_eval
import pickle
import pprint
pp = pprint.PrettyPrinter(depth=6)
matplotlib.rcParams['figure.figsize'] = (15.0, 5.0)
pd.set_option('display.max_columns', 150)

# %% [markdown]
# import os
# thedir = 'rtp-torrent'
# dirs = [name for name in os.listdir(thedir) if os.path.isdir(os.path.join(thedir, name))]
# projects = [dirname.replace("@", "/") for dirname in dirs if "@" in dirname]
# projects

# %%
folder = "../../../tmp"

# %%
for chunk in  pd.read_csv(f"{folder}/travistorrent_8_2_2017.csv", chunksize=10):
    cols = print(chunk.columns)
    break
# Out:
# Index(['tr_build_id', 'gh_project_name', 'gh_is_pr', 'gh_pr_created_at',
#        'gh_pull_req_num', 'gh_lang', 'git_merged_with', 'git_branch',
#        'gh_num_commits_in_push', 'gh_commits_in_push',
#        'git_prev_commit_resolution_status', 'git_prev_built_commit',
#        'tr_prev_build', 'gh_first_commit_created_at', 'gh_team_size',
#        'git_all_built_commits', 'git_num_all_built_commits',
#        'git_trigger_commit', 'tr_virtual_merged_into', 'tr_original_commit',
#        'gh_num_issue_comments', 'gh_num_commit_comments', 'gh_num_pr_comments',
#        'git_diff_src_churn', 'git_diff_test_churn', 'gh_diff_files_added',
#        'gh_diff_files_deleted', 'gh_diff_files_modified',
#        'gh_diff_tests_added', 'gh_diff_tests_deleted', 'gh_diff_src_files',
#        'gh_diff_doc_files', 'gh_diff_other_files',
#        'gh_num_commits_on_files_touched', 'gh_sloc', 'gh_test_lines_per_kloc',
#        'gh_test_cases_per_kloc', 'gh_asserts_cases_per_kloc',
#        'gh_by_core_team_member', 'gh_description_complexity', 'gh_pushed_at',
#        'gh_build_started_at', 'tr_status', 'tr_duration', 'tr_jobs',
#        'tr_build_number', 'tr_job_id', 'tr_log_lan', 'tr_log_status',
#        'tr_log_setup_time', 'tr_log_analyzer', 'tr_log_frameworks',
#        'tr_log_bool_tests_ran', 'tr_log_bool_tests_failed',
#        'tr_log_num_tests_ok', 'tr_log_num_tests_failed',
#        'tr_log_num_tests_run', 'tr_log_num_tests_skipped',
#        'tr_log_tests_failed', 'tr_log_testduration', 'tr_log_buildduration',
#        'build_successful'],
#       dtype='object')

# %%
df = pd.read_csv(f"{folder}/travis_projects.csv", index_col=0)
df
# Out:
#          tr_build_id           gh_project_name  gh_is_pr gh_pr_created_at  \
# 146754       1053608      adamfisk/LittleProxy     False              NaN
# 151226       1104002  Graylog2/graylog2-server     False              NaN
# 151227       1104009  Graylog2/graylog2-server     False              NaN
# 151233       1104095  Graylog2/graylog2-server     False              NaN
# 151234       1104114  Graylog2/graylog2-server     False              NaN
# ...              ...                       ...       ...              ...
# 3702126    156625515             DSpace/DSpace     False              NaN
# 3702186    156630332             facebook/buck     False              NaN
# 3702253    156635590             DSpace/DSpace     False              NaN
# 3702265    156637933             facebook/buck     False              NaN
# 3702522    156661290             facebook/buck     False              NaN
#
#          gh_pull_req_num gh_lang git_merged_with git_branch  \
# 146754               NaN    java             NaN     master
# 151226               NaN    java             NaN     master
# 151227               NaN    java             NaN    develop
# 151233               NaN    java             NaN    develop
# 151234               NaN    java             NaN    develop
# ...                  ...     ...             ...        ...
# 3702126              NaN    java             NaN     master
# 3702186              NaN    java             NaN     master
# 3702253              NaN    java             NaN     master
# 3702265              NaN    java             NaN     master
# 3702522              NaN    java             NaN     master
#
#          gh_num_commits_in_push  \
# 146754                      1.0
# 151226                      1.0
# 151227                      1.0
# 151233                     10.0
# 151234                      1.0
# ...                         ...
# 3702126                     NaN
# 3702186                     NaN
# 3702253                     NaN
# 3702265                     NaN
# 3702522                     NaN
#
#                                         gh_commits_in_push  \
# 146754            e8f1b0f7334229a4cbf91131e3757f10bb43ce24
# 151226            9bace34b804cb936aefd11efe4e28ef69041d125
# 151227            e67571d90c1a7811aa97e084d4bed790fcd3d564
# 151233   e67571d90c1a7811aa97e084d4bed790fcd3d564#ef267...
# 151234            5bb2792d334e8b4e7770a7de7fc0babadf5841d9
# ...                                                    ...
# 3702126                                                NaN
# 3702186                                                NaN
# 3702253                                                NaN
# 3702265                                                NaN
# 3702522                                                NaN
#
#         git_prev_commit_resolution_status  \
# 146754                        merge_found
# 151226                        merge_found
# 151227                        merge_found
# 151233                        build_found
# 151234                        build_found
# ...                                   ...
# 3702126                       merge_found
# 3702186                       build_found
# 3702253                       merge_found
# 3702265                       build_found
# 3702522                       build_found
#
#                             git_prev_built_commit  tr_prev_build  \
# 146754                                        NaN            NaN
# 151226                                        NaN            NaN
# 151227                                        NaN            NaN
# 151233   e67571d90c1a7811aa97e084d4bed790fcd3d564      1104009.0
# 151234   ef2675615047945cbb9ec6e473b76f4b8e9fcd80      1104095.0
# ...                                           ...            ...
# 3702126                                       NaN            NaN
# 3702186  4a89304f3d4c7afcec40050fae70e1dc896a9a08    156614718.0
# 3702253                                       NaN            NaN
# 3702265  17e0e7094562ac71c5441dd56cce4e636e90da36    156630332.0
# 3702522  a85ac01f6165b88f6a8cfc3f3d6981baaebe5d9b    156637933.0
#
#         gh_first_commit_created_at  gh_team_size  \
# 146754         2012-04-10 01:34:54             7
# 151226         2012-03-01 16:45:57             8
# 151227         2012-04-16 11:39:14             8
# 151233         2012-04-11 21:34:01             8
# 151234         2012-04-16 11:52:13             8
# ...                            ...           ...
# 3702126                        NaN            32
# 3702186                        NaN            38
# 3702253                        NaN            32
# 3702265                        NaN            38
# 3702522                        NaN            37
#
#                                      git_all_built_commits  \
# 146754   e8f1b0f7334229a4cbf91131e3757f10bb43ce24#eb60e...
# 151226   9bace34b804cb936aefd11efe4e28ef69041d125#80030...
# 151227   e67571d90c1a7811aa97e084d4bed790fcd3d564#7e772...
# 151233            ef2675615047945cbb9ec6e473b76f4b8e9fcd80
# 151234            5bb2792d334e8b4e7770a7de7fc0babadf5841d9
# ...                                                    ...
# 3702126           6b790a3c21179d5b34ce64f9f6f428f4e66aeb2a
# 3702186  17e0e7094562ac71c5441dd56cce4e636e90da36#caae9...
# 3702253           ad4d1a8de3a5d63e11147c9268dd49bd708bae9a
# 3702265           a85ac01f6165b88f6a8cfc3f3d6981baaebe5d9b
# 3702522           585fa618233d725321389f1d03faec95f01b6993
#
#          git_num_all_built_commits                        git_trigger_commit  \
# 146754                           2  e8f1b0f7334229a4cbf91131e3757f10bb43ce24
# 151226                           5  9bace34b804cb936aefd11efe4e28ef69041d125
# 151227                           5  e67571d90c1a7811aa97e084d4bed790fcd3d564
# 151233                           1  ef2675615047945cbb9ec6e473b76f4b8e9fcd80
# 151234                           1  5bb2792d334e8b4e7770a7de7fc0babadf5841d9
# ...                            ...                                       ...
# 3702126                          1  6b790a3c21179d5b34ce64f9f6f428f4e66aeb2a
# 3702186                          2  17e0e7094562ac71c5441dd56cce4e636e90da36
# 3702253                          1  ad4d1a8de3a5d63e11147c9268dd49bd708bae9a
# 3702265                          1  a85ac01f6165b88f6a8cfc3f3d6981baaebe5d9b
# 3702522                          1  585fa618233d725321389f1d03faec95f01b6993
#
#         tr_virtual_merged_into                        tr_original_commit  \
# 146754                     NaN  e8f1b0f7334229a4cbf91131e3757f10bb43ce24
# 151226                     NaN  9bace34b804cb936aefd11efe4e28ef69041d125
# 151227                     NaN  e67571d90c1a7811aa97e084d4bed790fcd3d564
# 151233                     NaN  ef2675615047945cbb9ec6e473b76f4b8e9fcd80
# 151234                     NaN  5bb2792d334e8b4e7770a7de7fc0babadf5841d9
# ...                        ...                                       ...
# 3702126                    NaN  6b790a3c21179d5b34ce64f9f6f428f4e66aeb2a
# 3702186                    NaN  17e0e7094562ac71c5441dd56cce4e636e90da36
# 3702253                    NaN  ad4d1a8de3a5d63e11147c9268dd49bd708bae9a
# 3702265                    NaN  a85ac01f6165b88f6a8cfc3f3d6981baaebe5d9b
# 3702522                    NaN  585fa618233d725321389f1d03faec95f01b6993
#
#          gh_num_issue_comments  gh_num_commit_comments  gh_num_pr_comments  \
# 146754                     NaN                       0                 NaN
# 151226                     NaN                       0                 NaN
# 151227                     NaN                       1                 NaN
# 151233                     NaN                       0                 NaN
# 151234                     NaN                       0                 NaN
# ...                        ...                     ...                 ...
# 3702126                    NaN                       0                 NaN
# 3702186                    NaN                       0                 NaN
# 3702253                    NaN                       0                 NaN
# 3702265                    NaN                       0                 NaN
# 3702522                    NaN                       0                 NaN
#
#          git_diff_src_churn  git_diff_test_churn  gh_diff_files_added  \
# 146754                    1                  781                    4
# 151226                 3968                 1313                   29
# 151227                  963                    0                   13
# 151233                    2                    0                    1
# 151234                    0                    0                    0
# ...                     ...                  ...                  ...
# 3702126                   0                    2                    0
# 3702186                 558                  279                    4
# 3702253                 192                    0                    0
# 3702265                   0                    0                    0
# 3702522                 171                  142                    0
#
#          gh_diff_files_deleted  gh_diff_files_modified  gh_diff_tests_added  \
# 146754                       3                       6                    0
# 151226                       7                      84                    0
# 151227                       1                      15                    0
# 151233                       0                       1                    0
# 151234                       0                       1                    0
# ...                        ...                     ...                  ...
# 3702126                      0                       1                    0
# 3702186                      0                      10                    0
# 3702253                      0                      11                    0
# 3702265                      0                       1                    0
# 3702522                      3                       3                    0
#
#          gh_diff_tests_deleted  gh_diff_src_files  gh_diff_doc_files  \
# 146754                       0                 10                  0
# 151226                       0                115                  0
# 151227                       0                 27                  0
# 151233                       0                  1                  0
# 151234                       0                  0                  0
# ...                        ...                ...                ...
# 3702126                      0                  1                  0
# 3702186                      7                  9                  0
# 3702253                      0                  9                  0
# 3702265                      0                  0                  0
# 3702522                      0                  4                  0
#
#          gh_diff_other_files  gh_num_commits_on_files_touched  gh_sloc  \
# 146754                     3                               73     2870
# 151226                     7                              375     3652
# 151227                     2                              187     4225
# 151233                     1                                1     4225
# 151234                     1                                2     4225
# ...                      ...                              ...      ...
# 3702126                    0                               20   212584
# 3702186                    5                              553   235341
# 3702253                    2                              375   212662
# 3702265                    1                              109   235341
# 3702522                    2                               46   235213
#
#          gh_test_lines_per_kloc  gh_test_cases_per_kloc  \
# 146754               208.710801                5.923345
# 151226               473.986857               41.621030
# 151227               421.775148               36.686391
# 151233               421.775148               36.686391
# 151234               421.775148               36.686391
# ...                         ...                     ...
# 3702126               78.430173                3.556241
# 3702186              636.327712               19.775560
# 3702253               78.401407                3.554937
# 3702265              636.327712               19.775560
# 3702522              636.214835               19.777818
#
#          gh_asserts_cases_per_kloc  gh_by_core_team_member  \
# 146754                   11.846690                    True
# 151226                   55.859803                   False
# 151227                   49.704142                   False
# 151233                   49.704142                   False
# 151234                   49.704142                   False
# ...                            ...                     ...
# 3702126                   9.647951                    True
# 3702186                  51.227793                    True
# 3702253                   9.644412                    True
# 3702265                  51.227793                   False
# 3702522                  51.242916                    True
#
#          gh_description_complexity         gh_pushed_at  gh_build_started_at  \
# 146754                         NaN  2012-04-10 01:35:10  2012-04-10 01:37:30
# 151226                         NaN  2012-03-01 16:46:06  2012-04-16 11:37:17
# 151227                         NaN  2012-04-16 11:39:23  2012-04-16 11:42:01
# 151233                         NaN  2012-04-16 12:01:53  2012-04-16 11:52:28
# 151234                         NaN  2012-04-16 11:52:21  2012-04-16 11:54:59
# ...                            ...                  ...                  ...
# 3702126                        NaN                  NaN  2016-08-31 20:08:28
# 3702186                        NaN                  NaN  2016-08-31 20:36:41
# 3702253                        NaN                  NaN  2016-08-31 20:49:34
# 3702265                        NaN                  NaN  2016-08-31 20:58:56
# 3702522                        NaN                  NaN  2016-08-31 23:16:03
#
#         tr_status  tr_duration      tr_jobs  tr_build_number  tr_job_id  \
# 146754     failed       2148.0    [1053609]                1    1053609
# 151226     failed         22.0    [1104003]                1    1104003
# 151227     failed        147.0    [1104010]                2    1104010
# 151233     failed         21.0    [1104096]                3    1104096
# 151234     passed        200.0    [1104115]                4    1104115
# ...           ...          ...          ...              ...        ...
# 3702126    passed        547.0  [156625516]             3812  156625516
# 3702186   errored        261.0  [156630333]             2145  156630333
# 3702253    passed       1066.0  [156635591]             3813  156635591
# 3702265   errored        340.0  [156637934]             2147  156637934
# 3702522    passed       2084.0  [156661291]             2148  156661291
#
#         tr_log_lan tr_log_status  tr_log_setup_time tr_log_analyzer  \
# 146754        java       unknown                NaN      java-maven
# 151226        ruby       unknown                NaN            ruby
# 151227     unknown       unknown                NaN           plain
# 151233     unknown       unknown                NaN           plain
# 151234        java       unknown                NaN        java-ant
# ...            ...           ...                ...             ...
# 3702126       java            ok               31.0      java-maven
# 3702186       java       unknown              226.0        java-ant
# 3702253       java            ok               42.0      java-maven
# 3702265       java       unknown              302.0        java-ant
# 3702522       java            ok              284.0        java-ant
#
#         tr_log_frameworks  tr_log_bool_tests_ran tr_log_bool_tests_failed  \
# 146754              junit                   True                    False
# 151226                NaN                  False                      NaN
# 151227                NaN                  False                      NaN
# 151233                NaN                  False                      NaN
# 151234                NaN                  False                      NaN
# ...                   ...                    ...                      ...
# 3702126             junit                   True                    False
# 3702186               NaN                  False                      NaN
# 3702253             junit                   True                    False
# 3702265               NaN                  False                      NaN
# 3702522               NaN                  False                      NaN
#
#          tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 146754                   0.0                      0.0                   NaN
# 151226                   NaN                      NaN                   NaN
# 151227                   NaN                      NaN                   NaN
# 151233                   NaN                      NaN                   NaN
# 151234                   NaN                      NaN                   NaN
# ...                      ...                      ...                   ...
# 3702126                 14.0                      0.0                  14.0
# 3702186                  NaN                      NaN                   NaN
# 3702253                 14.0                      0.0                  14.0
# 3702265                  NaN                      NaN                   NaN
# 3702522                  NaN                      NaN                   NaN
#
#          tr_log_num_tests_skipped tr_log_tests_failed  tr_log_testduration  \
# 146754                        0.0                 NaN                 0.03
# 151226                        NaN                 NaN                  NaN
# 151227                        NaN                 NaN                  NaN
# 151233                        NaN                 NaN                  NaN
# 151234                        NaN                 NaN                  NaN
# ...                           ...                 ...                  ...
# 3702126                       0.0                 NaN               211.63
# 3702186                       NaN                 NaN                  NaN
# 3702253                       0.0                 NaN               256.01
# 3702265                       NaN                 NaN                  NaN
# 3702522                       NaN                 NaN                  NaN
#
#          tr_log_buildduration  build_successful
# 146754                    NaN             False
# 151226                    NaN             False
# 151227                    NaN             False
# 151233                    NaN             False
# 151234                    0.0              True
# ...                       ...               ...
# 3702126                   NaN              True
# 3702186                   NaN             False
# 3702253                   NaN              True
# 3702265                   NaN             False
# 3702522                  12.0              True
#
# [78123 rows x 62 columns]

# %%
df.columns
# Out:
# Index(['tr_build_id', 'gh_project_name', 'gh_is_pr', 'gh_pr_created_at',
#        'gh_pull_req_num', 'gh_lang', 'git_merged_with', 'git_branch',
#        'gh_num_commits_in_push', 'gh_commits_in_push',
#        'git_prev_commit_resolution_status', 'git_prev_built_commit',
#        'tr_prev_build', 'gh_first_commit_created_at', 'gh_team_size',
#        'git_all_built_commits', 'git_num_all_built_commits',
#        'git_trigger_commit', 'tr_virtual_merged_into', 'tr_original_commit',
#        'gh_num_issue_comments', 'gh_num_commit_comments', 'gh_num_pr_comments',
#        'git_diff_src_churn', 'git_diff_test_churn', 'gh_diff_files_added',
#        'gh_diff_files_deleted', 'gh_diff_files_modified',
#        'gh_diff_tests_added', 'gh_diff_tests_deleted', 'gh_diff_src_files',
#        'gh_diff_doc_files', 'gh_diff_other_files',
#        'gh_num_commits_on_files_touched', 'gh_sloc', 'gh_test_lines_per_kloc',
#        'gh_test_cases_per_kloc', 'gh_asserts_cases_per_kloc',
#        'gh_by_core_team_member', 'gh_description_complexity', 'gh_pushed_at',
#        'gh_build_started_at', 'tr_status', 'tr_duration', 'tr_jobs',
#        'tr_build_number', 'tr_job_id', 'tr_log_lan', 'tr_log_status',
#        'tr_log_setup_time', 'tr_log_analyzer', 'tr_log_frameworks',
#        'tr_log_bool_tests_ran', 'tr_log_bool_tests_failed',
#        'tr_log_num_tests_ok', 'tr_log_num_tests_failed',
#        'tr_log_num_tests_run', 'tr_log_num_tests_skipped',
#        'tr_log_tests_failed', 'tr_log_testduration', 'tr_log_buildduration',
#        'build_successful'],
#       dtype='object')

# %% [markdown]
# #### Number of builds per project

# %%
plt.figure(figsize=(15,5))

data=df.groupby("gh_project_name").count().tr_build_id
data=data.sort_values()

ax = sns.barplot(x=data.index,y=data.values)
ax.tick_params(axis='x', labelrotation= 90)
ax.set_title("Number of builds")
# Out:
# Text(0.5, 1.0, 'Number of builds')

# %% [markdown]
# #### Number of builds with test results

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x="gh_project_name",y="tr_log_bool_tests_ran",
                 data=df.groupby(df.gh_project_name).sum().tr_log_bool_tests_ran.reset_index().sort_values(by="tr_log_bool_tests_ran"))
ax.tick_params(axis='x', labelrotation= 90)
ax.set_title("Number of builds with test results")
# Out:
# Text(0.5, 1.0, 'Number of builds with test results')

# %% [markdown]
# #### Percentage of builds with test results

# %%
plt.figure(figsize=(15,5))

data=df.groupby("gh_project_name").sum().tr_log_bool_tests_ran/df.groupby("gh_project_name").tr_log_bool_tests_ran.count()
data=data.sort_values()

ax = sns.barplot(x=data.index,y=data.values)
ax.tick_params(axis='x', labelrotation= 90)
ax.set_title("Percentage of builds with test results")
# Out:
# Text(0.5, 1.0, 'Percentage of builds with test results')

# %% [markdown]
# ## In depth analysis of a project

# %%
project='SonarSource/sonarqube'

# %%
project_df = df[df.gh_project_name == project]
project_df.sort_values(by="tr_build_id").head(10)
# Out:
#          tr_build_id        gh_project_name  gh_is_pr gh_pr_created_at  \
# 2310262     54731125  SonarSource/sonarqube     False              NaN
# 2310263     54731125  SonarSource/sonarqube     False              NaN
# 2310282     54734500  SonarSource/sonarqube     False              NaN
# 2310283     54734500  SonarSource/sonarqube     False              NaN
# 2310327     54738299  SonarSource/sonarqube     False              NaN
# 2310328     54738299  SonarSource/sonarqube     False              NaN
# 2310522     54745798  SonarSource/sonarqube     False              NaN
# 2310523     54745798  SonarSource/sonarqube     False              NaN
# 2310847     54755692  SonarSource/sonarqube     False              NaN
# 2310848     54755692  SonarSource/sonarqube     False              NaN
#
#          gh_pull_req_num gh_lang git_merged_with                git_branch  \
# 2310262              NaN    java             NaN                    master
# 2310263              NaN    java             NaN                    master
# 2310282              NaN    java             NaN                    master
# 2310283              NaN    java             NaN                    master
# 2310327              NaN    java             NaN  latest-silver-master#476
# 2310328              NaN    java             NaN  latest-silver-master#476
# 2310522              NaN    java             NaN                    master
# 2310523              NaN    java             NaN                    master
# 2310847              NaN    java             NaN  latest-silver-master#477
# 2310848              NaN    java             NaN  latest-silver-master#477
#
#          gh_num_commits_in_push                        gh_commits_in_push  \
# 2310262                     1.0  a056b278e321bac091ea3d5fe1f21ad75854e273
# 2310263                     1.0  a056b278e321bac091ea3d5fe1f21ad75854e273
# 2310282                     1.0  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310283                     1.0  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310327                     1.0  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310328                     1.0  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310522                     1.0  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310523                     1.0  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310847                     1.0  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310848                     1.0  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
#
#         git_prev_commit_resolution_status  \
# 2310262                       merge_found
# 2310263                       merge_found
# 2310282                       build_found
# 2310283                       build_found
# 2310327                       build_found
# 2310328                       build_found
# 2310522                       build_found
# 2310523                       build_found
# 2310847                       build_found
# 2310848                       build_found
#
#                             git_prev_built_commit  tr_prev_build  \
# 2310262                                       NaN            NaN
# 2310263                                       NaN            NaN
# 2310282  a056b278e321bac091ea3d5fe1f21ad75854e273     54731125.0
# 2310283  a056b278e321bac091ea3d5fe1f21ad75854e273     54731125.0
# 2310327  a056b278e321bac091ea3d5fe1f21ad75854e273     54731125.0
# 2310328  a056b278e321bac091ea3d5fe1f21ad75854e273     54731125.0
# 2310522  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12     54738299.0
# 2310523  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12     54738299.0
# 2310847  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12     54738299.0
# 2310848  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12     54738299.0
#
#         gh_first_commit_created_at  gh_team_size  \
# 2310262        2015-03-17 15:02:55            21
# 2310263        2015-03-17 15:02:55            21
# 2310282        2015-03-17 15:19:11            21
# 2310283        2015-03-17 15:19:11            21
# 2310327        2015-03-17 15:19:11            21
# 2310328        2015-03-17 15:19:11            21
# 2310522        2015-03-17 16:45:26            21
# 2310523        2015-03-17 16:45:26            21
# 2310847        2015-03-17 16:45:26            21
# 2310848        2015-03-17 16:45:26            21
#
#                                      git_all_built_commits  \
# 2310262  a056b278e321bac091ea3d5fe1f21ad75854e273#15ee5...
# 2310263  a056b278e321bac091ea3d5fe1f21ad75854e273#15ee5...
# 2310282           0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310283           0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310327           0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310328           0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310522           dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310523           dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310847           dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310848           dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
#
#          git_num_all_built_commits                        git_trigger_commit  \
# 2310262                         14  a056b278e321bac091ea3d5fe1f21ad75854e273
# 2310263                         14  a056b278e321bac091ea3d5fe1f21ad75854e273
# 2310282                          1  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310283                          1  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310327                          1  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310328                          1  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310522                          1  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310523                          1  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310847                          1  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310848                          1  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
#
#         tr_virtual_merged_into                        tr_original_commit  \
# 2310262                    NaN  a056b278e321bac091ea3d5fe1f21ad75854e273
# 2310263                    NaN  a056b278e321bac091ea3d5fe1f21ad75854e273
# 2310282                    NaN  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310283                    NaN  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310327                    NaN  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310328                    NaN  0a5224287f9dd6a3f0d3098d2f21bb4c69023f12
# 2310522                    NaN  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310523                    NaN  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310847                    NaN  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
# 2310848                    NaN  dd574e51443d8c9dc64aa7d889f7f6f1281d9ec5
#
#          gh_num_issue_comments  gh_num_commit_comments  gh_num_pr_comments  \
# 2310262                    NaN                       0                 NaN
# 2310263                    NaN                       0                 NaN
# 2310282                    NaN                       0                 NaN
# 2310283                    NaN                       0                 NaN
# 2310327                    NaN                       0                 NaN
# 2310328                    NaN                       0                 NaN
# 2310522                    NaN                       0                 NaN
# 2310523                    NaN                       0                 NaN
# 2310847                    NaN                       0                 NaN
# 2310848                    NaN                       0                 NaN
#
#          git_diff_src_churn  git_diff_test_churn  gh_diff_files_added  \
# 2310262                4112                  870                   41
# 2310263                4112                  870                   41
# 2310282                   0                  184                    3
# 2310283                   0                  184                    3
# 2310327                   0                  184                    3
# 2310328                   0                  184                    3
# 2310522                  81                    0                    0
# 2310523                  81                    0                    0
# 2310847                  81                    0                    0
# 2310848                  81                    0                    0
#
#          gh_diff_files_deleted  gh_diff_files_modified  gh_diff_tests_added  \
# 2310262                      5                      84                    0
# 2310263                      5                      84                    0
# 2310282                      0                       3                    0
# 2310283                      0                       3                    0
# 2310327                      0                       3                    0
# 2310328                      0                       3                    0
# 2310522                      0                       3                    0
# 2310523                      0                       3                    0
# 2310847                      0                       3                    0
# 2310848                      0                       3                    0
#
#          gh_diff_tests_deleted  gh_diff_src_files  gh_diff_doc_files  \
# 2310262                      0                 81                  4
# 2310263                      0                 81                  4
# 2310282                      5                  5                  0
# 2310283                      5                  5                  0
# 2310327                      5                  5                  0
# 2310328                      5                  5                  0
# 2310522                      0                  2                  1
# 2310523                      0                  2                  1
# 2310847                      0                  2                  1
# 2310848                      0                  2                  1
#
#          gh_diff_other_files  gh_num_commits_on_files_touched  gh_sloc  \
# 2310262                   37                             1367   139469
# 2310263                   37                             1367   139469
# 2310282                    1                                7   139469
# 2310283                    1                                7   139469
# 2310327                    1                                7   139469
# 2310328                    1                                7   139469
# 2310522                    0                               17   139469
# 2310523                    0                               17   139469
# 2310847                    0                               17   139469
# 2310848                    0                               17   139469
#
#          gh_test_lines_per_kloc  gh_test_cases_per_kloc  \
# 2310262              749.829711               44.834336
# 2310263              749.829711               44.834336
# 2310282              750.654267               44.870186
# 2310283              750.654267               44.870186
# 2310327              750.654267               44.870186
# 2310328              750.654267               44.870186
# 2310522              750.654267               44.870186
# 2310523              750.654267               44.870186
# 2310847              750.654267               44.870186
# 2310848              750.654267               44.870186
#
#          gh_asserts_cases_per_kloc  gh_by_core_team_member  \
# 2310262                 120.141393                    True
# 2310263                 120.141393                    True
# 2310282                 120.277624                    True
# 2310283                 120.277624                    True
# 2310327                 120.277624                    True
# 2310328                 120.277624                    True
# 2310522                 120.277624                    True
# 2310523                 120.277624                    True
# 2310847                 120.277624                    True
# 2310848                 120.277624                    True
#
#          gh_description_complexity         gh_pushed_at  gh_build_started_at  \
# 2310262                        NaN  2015-03-17 15:03:10  2015-03-17 15:04:32
# 2310263                        NaN  2015-03-17 15:03:10  2015-03-17 15:04:32
# 2310282                        NaN  2015-03-17 15:25:59  2015-03-17 15:27:56
# 2310283                        NaN  2015-03-17 15:25:59  2015-03-17 15:27:56
# 2310327                        NaN  2015-03-17 15:25:59  2015-03-17 15:53:09
# 2310328                        NaN  2015-03-17 15:25:59  2015-03-17 15:53:09
# 2310522                        NaN  2015-03-17 16:45:36  2015-03-17 16:46:00
# 2310523                        NaN  2015-03-17 16:45:36  2015-03-17 16:46:00
# 2310847                        NaN  2015-03-17 16:45:36  2015-03-17 17:53:28
# 2310848                        NaN  2015-03-17 16:45:36  2015-03-17 17:53:28
#
#         tr_status  tr_duration               tr_jobs  tr_build_number  \
# 2310262    failed        255.0  [54731126, 54731127]                1
# 2310263    failed        255.0  [54731126, 54731127]                1
# 2310282    failed        254.0  [54734501, 54734502]                2
# 2310283    failed        254.0  [54734501, 54734502]                2
# 2310327    failed        272.0  [54738300, 54738301]                3
# 2310328    failed        272.0  [54738300, 54738301]                3
# 2310522    failed        245.0  [54745799, 54745800]                4
# 2310523    failed        245.0  [54745799, 54745800]                4
# 2310847    failed        217.0  [54755694, 54755695]                5
# 2310848    failed        217.0  [54755694, 54755695]                5
#
#          tr_job_id tr_log_lan tr_log_status  tr_log_setup_time  \
# 2310262   54731127       java        broken                3.0
# 2310263   54731126       java        broken                4.0
# 2310282   54734502       java        broken                3.0
# 2310283   54734501       java        broken                3.0
# 2310327   54738300       java        broken                3.0
# 2310328   54738301       java        broken                3.0
# 2310522   54745799       java        broken                4.0
# 2310523   54745800       java        broken                3.0
# 2310847   54755694       java        broken                4.0
# 2310848   54755695       java        broken                3.0
#
#         tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 2310262        java-ant               NaN                  False
# 2310263        java-ant               NaN                  False
# 2310282        java-ant               NaN                  False
# 2310283        java-ant               NaN                  False
# 2310327        java-ant               NaN                  False
# 2310328        java-ant               NaN                  False
# 2310522        java-ant               NaN                  False
# 2310523        java-ant               NaN                  False
# 2310847        java-ant               NaN                  False
# 2310848        java-ant               NaN                  False
#
#         tr_log_bool_tests_failed  tr_log_num_tests_ok  \
# 2310262                      NaN                  NaN
# 2310263                      NaN                  NaN
# 2310282                      NaN                  NaN
# 2310283                      NaN                  NaN
# 2310327                      NaN                  NaN
# 2310328                      NaN                  NaN
# 2310522                      NaN                  NaN
# 2310523                      NaN                  NaN
# 2310847                      NaN                  NaN
# 2310848                      NaN                  NaN
#
#          tr_log_num_tests_failed  tr_log_num_tests_run  \
# 2310262                      NaN                   NaN
# 2310263                      NaN                   NaN
# 2310282                      NaN                   NaN
# 2310283                      NaN                   NaN
# 2310327                      NaN                   NaN
# 2310328                      NaN                   NaN
# 2310522                      NaN                   NaN
# 2310523                      NaN                   NaN
# 2310847                      NaN                   NaN
# 2310848                      NaN                   NaN
#
#          tr_log_num_tests_skipped tr_log_tests_failed  tr_log_testduration  \
# 2310262                       NaN                 NaN                  NaN
# 2310263                       NaN                 NaN                  NaN
# 2310282                       NaN                 NaN                  NaN
# 2310283                       NaN                 NaN                  NaN
# 2310327                       NaN                 NaN                  NaN
# 2310328                       NaN                 NaN                  NaN
# 2310522                       NaN                 NaN                  NaN
# 2310523                       NaN                 NaN                  NaN
# 2310847                       NaN                 NaN                  NaN
# 2310848                       NaN                 NaN                  NaN
#
#          tr_log_buildduration  build_successful
# 2310262                 90.00             False
# 2310263                108.00             False
# 2310282                 79.00             False
# 2310283                105.00             False
# 2310327                105.00             False
# 2310328                 59.54             False
# 2310522                 89.00             False
# 2310523                 76.00             False
# 2310847                 79.00             False
# 2310848                 60.00             False

# %%
project_df.shape
# Out:
# (30142, 62)

# %% [markdown]
# **Count lines containing the project name**
#
# Make sure all lines for the project are correctly imported in pandas

# %%
num_rows = 0
for row in open(f"{folder}/travistorrent_8_2_2017.csv"):
    if(project in row):
        num_rows += 1
num_rows == len(project_df)
# Out:
# True

# %% [markdown]
# ### Missing builds from TraviTorrent
# TraviCI uses an incremental build_number. All the builds up to the highest build_number for the project should be present in the dataset

# %%
max_build_number = project_df.tr_build_number.max()
n_missing_builds = max_build_number - len(project_df.tr_build_number.unique())
n_missing_builds
# Out:
# 8222

# %%
len(project_df.tr_build_number.unique())
# Out:
# 4690

# %% [markdown]
# Let's plot the distribution of build_numbers to visualize if older builds are the ones more affected by this problem

# %%
missing_build_numbers = []
build_numbers = project_df.tr_build_number.unique()
for i in range(0, project_df.tr_build_number.max()):
    if i not in build_numbers:
        missing_build_numbers.append(i)
sns.distplot(missing_build_numbers)
plt.axvline(max_build_number, 0, 10, color="r")

# %% [markdown]
# The problem seems to affect builds up until the very last build present in the dataset (the red line)

# %% [markdown]
# **Total number of builds for the project in TravisTorrent**

# %%
len(project_df.tr_build_id.unique())
# Out:
# 4690

# %%
len(project_df.tr_build_id.unique()) + n_missing_builds == max_build_number
# Out:
# True

# %%
project_df[[col for col in project_df if col.startswith("tr_log")]].describe()
# Out:
#        tr_log_setup_time  tr_log_num_tests_ok  tr_log_num_tests_failed  \
# count       29929.000000         16846.000000             16846.000000
# mean            3.917839           133.656536                 0.023448
# std             4.571636           222.944923                 0.460602
# min             0.000000             0.000000                 0.000000
# 25%             3.000000             4.000000                 0.000000
# 50%             4.000000            49.000000                 0.000000
# 75%             4.000000            98.000000                 0.000000
# max           385.000000          5597.000000                21.000000
#
#        tr_log_num_tests_run  tr_log_num_tests_skipped  tr_log_testduration  \
# count          15755.000000              16846.000000         16853.000000
# mean             142.937036                  5.219518           279.699226
# std              227.670216                  9.492445           237.153014
# min                1.000000                  0.000000             0.000000
# 25%               17.000000                  0.000000            51.900000
# 50%               49.000000                  0.000000           245.940000
# 75%               98.000000                  4.000000           433.800000
# max             5598.000000                 26.000000          1216.600000
#
#        tr_log_buildduration
# count          22978.000000
# mean             469.346592
# std              320.560954
# min                0.000000
# 25%              133.000000
# 50%              452.000000
# 75%              737.000000
# max             2723.000000

# %% [markdown]
# plt.figure(figsize=(15,5))
# plt.locator_params(axis='x', nbins=6)
# ax = sns.lineplot(x="tr_build_id", y="tr_log_num_tests_run", data=project_df[["tr_build_id","tr_log_num_tests_run"]])
# for ind, label in enumerate(ax.get_xticklabels()):
#     if ind % 20 == 0:  # every 10th label is kept
#         label.set_visible(True)
#     else:
#         label.set_visible(False)

# %% [markdown]
# ## Import RTPTorrent dataset
# This dataset contains class specific test metrics for the project's builds

# %%
sonar_rtp = pd.read_csv(f"{folder}/rtp-torrent/SonarSource@sonarqube/SonarSource@sonarqube.csv")
sonar_rtp
# Out:
#           travisJobId                                           testName  \
# 0           137788147                       org.sonar.test.TestUtilsTest
# 1           137788147                      org.sonar.test.JsonAssertTest
# 2           137788147               org.sonar.test.i18n.I18nMatchersTest
# 3           137788147                  org.sonar.test.JsonComparisonTest
# 4           137788147  org.sonar.test.i18n.BundleSynchronizedMatcherTest
# ...               ...                                                ...
# 17134768    100821699             org.sonar.application.PropsBuilderTest
# 17134769    100821699        org.sonar.application.CommandLineParserTest
# 17134770    100821699             org.sonar.application.JdbcSettingsTest
# 17134771    100821699                      org.sonar.application.AppTest
# 17134772     95537922                                    it.PluginsSuite
#
#           index  duration  count  failures  errors  skipped
# 0             0     0.298      4         0       0        0
# 1             1     0.266      7         0       0        0
# 2             2     0.015      2         0       0        0
# 3             3     0.038     12         0       0        0
# 4             4     0.025      9         0       0        0
# ...         ...       ...    ...       ...     ...      ...
# 17134768   1421     0.198      7         0       0        0
# 17134769   1422     0.005      2         0       0        0
# 17134770   1423     0.033     10         0       0        0
# 17134771   1424     0.052      6         0       0        0
# 17134772      0   214.441      2         0       0        0
#
# [17134773 rows x 8 columns]

# %% [markdown]
# ## TravisTorrent and RTPTorrent merging

# %% [markdown]
# **Are all the jobs' builds from RTPTorrent present in TravisTorrent dataset?**

# %%
rt_jobIds = sonar_rtp.travisJobId.unique()

# %%
travis_jobsIds = project_df.tr_job_id.unique()

# %%
len(set(rt_jobIds) - set(travis_jobsIds))
# Out:
# 32321

# %%
(len(set(jobIds) - set(jobIds2)))/len(jobIds)
# Out:
# 0.6063181195715385

# %% [markdown]
# More than 60% of the builds are missing from TravisTorrent

# %%
jobIds2[-1]
# Out:
# 156501166

# %% [markdown]
# ### TravisCI info for the project

# %%
from travispy import TravisPy

# %%
t = TravisPy()
repo = t.repo(project)

# %%
repo.last_build_number
# Out:
# '39429'

# %%
builds = t.builds(repository_id = repo.id, number = 1)
print(builds[0].started_at)
# Out:
# 2015-03-17T15:04:32Z

# %% [markdown]
# * To this day, the project has over 39420 builds on TraviCI
# * The first available build on TravisCI dates 17/3/2015

# %%
builds = t.builds(repository_id = repo.id, after_number = 10)
len(builds)
# Out:
# 9

# %%
pp.pprint(builds[0].__slots__)
# Out:
# ['repository_id',
#  'commit_id',
#  'number',
#  'pull_request',
#  'pull_request_title',
#  'pull_request_number',
#  'config',
#  'started_at',
#  'finished_at',
#  'duration',
#  'job_ids',
#  'jobs',
#  'commit']

# %%
builds[0].__slots__
# Out:
# ['repository_id',
#  'commit_id',
#  'number',
#  'pull_request',
#  'pull_request_title',
#  'pull_request_number',
#  'config',
#  'started_at',
#  'finished_at',
#  'duration',
#  'job_ids',
#  'jobs',
#  'commit']

# %%
builds[0].job_ids
# Out:
# [54834267, 54834268]

# %% [markdown]
# ## TravisCI builds for the project

# %%
import glob

# %%
v2_files = glob.glob("builds/v2/*.pkl")
v3_files = glob.glob("builds/v3/*.pkl")

# %%
with open(v2_files[0], 'rb') as f:
    builds2 = pickle.load(f)
v2_fields = builds2[0].keys()
v2_fields
# Out:
# dict_keys(['id', 'repository_id', 'commit_id', 'number', 'event_type', 'pull_request', 'pull_request_title', 'pull_request_number', 'config', 'state', 'started_at', 'finished_at', 'duration', 'job_ids'])

# %%
pp.pprint(builds2[0])
# Out:
# {'commit_id': 28112504,
#  'config': {'.result': 'configured',
#             'before_cache': ['find ~/.m2/repository -type d -name \\*-SNAPSHOT '
#                              '-exec rm -rf {} \\;',
#                              'find ~/.m2/repository -name maven-metadata-\\* '
#                              '-exec rm {} \\;',
#                              'find ~/.m2/repository -name '
#                              'resolver-status.properties -exec rm {} \\;'],
#             'cache': {'directories': ['$HOME/.m2/repository',
#                                       '$HOME/.sonar',
#                                       'server/sonar-web/node',
#                                       'server/sonar-web/node_modules']},
#             'dist': 'precise',
#             'env': ['TARGET=CI',
#                     'TARGET=IT IT_CATEGORY=Category1',
#                     'TARGET=IT IT_CATEGORY=Category2',
#                     'TARGET=IT IT_CATEGORY=Category3',
#                     'TARGET=IT IT_CATEGORY=Category4',
#                     'TARGET=IT IT_CATEGORY=Plugins',
#                     'TARGET=POSTGRES',
#                     'TARGET=MYSQL',
#                     'TARGET=WEB'],
#             'group': 'stable',
#             'install': True,
#             'jdk': 'oraclejdk7',
#             'language': 'java',
#             'matrix': {'fast_finish': True},
#             'notifications': {'email': False},
#             'script': './travis.sh',
#             'sudo': False},
#  'duration': 5361,
#  'event_type': 'push',
#  'finished_at': '2015-12-28T16:34:08Z',
#  'id': 99118995,
#  'job_ids': [99118996,
#              99118997,
#              99118998,
#              99118999,
#              99119000,
#              99119001,
#              99119002,
#              99119003,
#              99119004],
#  'number': '6995',
#  'pull_request': False,
#  'pull_request_number': None,
#  'pull_request_title': None,
#  'repository_id': 234484,
#  'started_at': '2015-12-28T16:18:41Z',
#  'state': 'failed'}

# %%
with open(v3_files[0], 'rb') as f:
    builds3 = pickle.load(f)
v3_fields = builds3[0].keys()
v3_fields
# Out:
# dict_keys(['@type', '@href', '@representation', '@permissions', 'id', 'number', 'state', 'duration', 'event_type', 'previous_state', 'pull_request_title', 'pull_request_number', 'started_at', 'finished_at', 'private', 'repository', 'branch', 'tag', 'commit', 'jobs', 'stages', 'created_by', 'updated_at'])

# %%
pp.pprint(builds3[0])
# Out:
# {'@href': '/build/264330283',
#  '@permissions': {'cancel': False, 'read': True, 'restart': False},
#  '@representation': 'standard',
#  '@type': 'build',
#  'branch': {'@href': '/repo/234484/branch/janos%2Fvalidate-branch-config2',
#             '@representation': 'minimal',
#             '@type': 'branch',
#             'name': 'janos/validate-branch-config2'},
#  'commit': {'@representation': 'minimal',
#             '@type': 'commit',
#             'committed_at': '2017-08-14T11:50:13Z',
#             'compare_url': 'https://github.com/SonarSource/sonarqube/compare/5857120b9aed...a23fba6ffb44',
#             'id': 76913412,
#             'message': 'Add incrementalMode param to '
#                        'BrnachConfigurationValidator.validate',
#             'ref': 'refs/heads/janos/validate-branch-config2',
#             'sha': 'a23fba6ffb44e00b09009e8032bd42517479225e'},
#  'created_by': {'@href': '/user/437829',
#                 '@representation': 'minimal',
#                 '@type': 'user',
#                 'id': 437829,
#                 'login': 'janos-ss'},
#  'duration': 365,
#  'event_type': 'push',
#  'finished_at': '2017-08-14T11:54:45Z',
#  'id': 264330283,
#  'jobs': [{'@href': '/job/264330284',
#            '@representation': 'minimal',
#            '@type': 'job',
#            'id': 264330284},
#           {'@href': '/job/264330285',
#            '@representation': 'minimal',
#            '@type': 'job',
#            'id': 264330285}],
#  'number': '28427',
#  'previous_state': 'failed',
#  'private': False,
#  'pull_request_number': None,
#  'pull_request_title': None,
#  'repository': {'@href': '/repo/234484',
#                 '@representation': 'minimal',
#                 '@type': 'repository',
#                 'id': 234484,
#                 'name': 'sonarqube',
#                 'slug': 'SonarSource/sonarqube'},
#  'stages': [],
#  'started_at': '2017-08-14T11:51:17Z',
#  'state': 'failed',
#  'tag': None,
#  'updated_at': '2019-04-10T10:45:46.396Z'}

# %%
common_fields = set(v3_fields).intersection(set(v2_fields))
common_fields
# Out:
# {'duration',
#  'event_type',
#  'finished_at',
#  'id',
#  'number',
#  'pull_request_number',
#  'pull_request_title',
#  'started_at',
#  'state'}

# %%
uncommon_fields = set(v3_fields).symmetric_difference(set(v2_fields))
uncommon_fields
# Out:
# {'@href',
#  '@permissions',
#  '@representation',
#  '@type',
#  'branch',
#  'commit',
#  'commit_id',
#  'config',
#  'created_by',
#  'job_ids',
#  'jobs',
#  'previous_state',
#  'private',
#  'pull_request',
#  'repository',
#  'repository_id',
#  'stages',
#  'tag',
#  'updated_at'}

# %% [markdown]
# ## Builds retrival

# %%
builds_tuple = []

# %% [markdown]
# #### Version 2 retrieval

# %%
for v2_file in v2_files:
    with open(v2_file, 'rb') as f:
        builds2 = pickle.load(f)
        for build in builds2:
            build_values = []
            for field in common_fields:
                build_values.append(build[field])
            builds_tuple.append(tuple(build_values))

# %% [markdown]
# #### Version 3 retrieval

# %%
for v3_file in v3_files:
    with open(v3_file, 'rb') as f:
        builds3 = pickle.load(f)
        for build in builds3:
            build_values = []
            for field in common_fields:
                build_values.append(build[field])
            builds_tuple.append(tuple(build_values))

# %%
buildsDf = pd.DataFrame(builds_tuple, columns = common_fields)
buildsDf
# Out:
#       number  pull_request_number         id    event_type  \
# 0       6995                  NaN   99118995          push
# 1       6994                  NaN   99100662          push
# 2       6993                  NaN   99093472          push
# 3       6992                  NaN   99086186          push
# 4       6991                  NaN   99078711          push
# ...      ...                  ...        ...           ...
# 39378  36432                  NaN  338500570          push
# 39379  36431                  NaN  338500019          push
# 39380  36430                  NaN  338499772          push
# 39381  36429               3028.0  338498110  pull_request
# 39382  36428                  NaN  338498094          push
#
#                 finished_at                     pull_request_title  \
# 0      2015-12-28T16:34:08Z                                   None
# 1      2015-12-28T14:36:03Z                                   None
# 2      2015-12-28T13:27:51Z                                   None
# 3      2015-12-28T12:18:41Z                                   None
# 4      2015-12-28T10:56:34Z                                   None
# ...                     ...                                    ...
# 39378  2018-02-07T13:38:25Z                                   None
# 39379  2018-02-07T13:45:47Z                                   None
# 39380  2018-02-07T13:57:02Z                                   None
# 39381  2018-02-07T13:48:27Z  SONAR-10364 upgrade protobuf to 3.2.0
# 39382  2018-02-07T13:31:50Z                                   None
#
#                  started_at  duration   state
# 0      2015-12-28T16:18:41Z    5361.0  failed
# 1      2015-12-28T14:18:30Z    5953.0  passed
# 2      2015-12-28T13:11:39Z    5166.0  passed
# 3      2015-12-28T12:10:56Z    5243.0  passed
# 4      2015-12-28T10:41:16Z    5045.0  passed
# ...                     ...       ...     ...
# 39378  2018-02-07T13:36:19Z     191.0  passed
# 39379  2018-02-07T13:35:06Z     859.0  failed
# 39380  2018-02-07T13:34:31Z    1543.0  passed
# 39381  2018-02-07T13:29:37Z    1331.0  passed
# 39382  2018-02-07T13:29:33Z     203.0  passed
#
# [39383 rows x 9 columns]

# %%
buildsDf["number"] = pd.to_numeric(buildsDf.number)

# %% [markdown]
# **Build numbers with multiple build_ids**

# %%
(buildsDf.groupby("number").count().id > 1).sum()
# Out:
# 87

# %% [markdown]
# **Number of missing build numbers**

# %%
buildsDf.number.max() - buildsDf.number.min() - len(buildsDf.number.unique()) > 0
# Out:
# True

# %% [markdown]
# **Numbers of the missing builds**

# %%
t = buildsDf.number.unique()
missing_numbers = []
for i in range(1, buildsDf.number.max()):
    if i in t:
        continue
    missing_numbers.append(i)

# %%
len(missing_numbers)
# Out:
# 131

# %%
import travis2
import travis

# %% [markdown]
# bs=[]
# for number in missing_numbers:
#     bs.append(travis2.get_builds({"repository_id": "234484", "number":  number})["builds"][0])

# %%
len(bs) == len(missing_numbers)
# Out:
# True

# %% [markdown]
# with open("builds/all_missing_builds.pkl", "wb") as f:
#     pickle.dump(bs, f)

# %%
with open("builds/all_missing_builds.pkl", "rb") as f:
    bs = pickle.load(f)

# %%
missing_builds_tuple = []
for build in bs:
    missing_build_values = []
    for field in common_fields:
        missing_build_values.append(build[field])
    missing_builds_tuple.append(tuple(missing_build_values))

# %%
missingBuildsDf = pd.DataFrame(missing_builds_tuple, columns = common_fields)
missingBuildsDf
# Out:
#     number  pull_request_number         id    event_type  \
# 0    12036                  NaN  146408985          push
# 1    12037                  NaN  146424734          push
# 2    12038                  NaN  146426111          push
# 3    12039                  NaN  146451986          push
# 4    12040               1114.0  146451994  pull_request
# ..     ...                  ...        ...           ...
# 126  12162               1121.0  148002763  pull_request
# 127  12163                  NaN  148005346          push
# 128  12164               1121.0  148005355  pull_request
# 129  12165               1121.0  148010751  pull_request
# 130  12166                  NaN  148010754          push
#
#               finished_at                    pull_request_title  \
# 0    2016-07-21T16:33:47Z                                  None
# 1    2016-07-21T17:22:32Z                                  None
# 2    2016-07-21T16:58:39Z                                  None
# 3    2016-07-21T18:15:08Z                                  None
# 4    2016-07-21T18:22:17Z  feature/sb/improve-disabled-projects
# ..                    ...                                   ...
# 126  2016-07-28T11:22:06Z    Provide WS to manage project links
# 127  2016-07-28T11:33:17Z                                  None
# 128  2016-07-28T11:34:11Z    Provide WS to manage project links
# 129  2016-07-28T12:02:21Z    Provide WS to manage project links
# 130  2016-07-28T12:01:12Z                                  None
#
#                started_at  duration     state
# 0    2016-07-21T16:14:01Z      1292    passed
# 1    2016-07-21T16:55:14Z      1723    passed
# 2    2016-07-21T16:57:32Z        46   errored
# 3    2016-07-21T18:13:39Z       171  canceled
# 4    2016-07-21T18:13:40Z       772    failed
# ..                    ...       ...       ...
# 126  2016-07-28T10:59:31Z      1431    passed
# 127  2016-07-28T11:13:59Z      1232    passed
# 128  2016-07-28T11:14:09Z      1279    passed
# 129  2016-07-28T11:41:56Z      1338    passed
# 130  2016-07-28T11:41:56Z      1239    passed
#
# [131 rows x 9 columns]

# %%
allBuilds = buildsDf.append(missingBuildsDf)

# %%
allBuilds
# Out:
#     number  pull_request_number         id    event_type  \
# 0     6995                  NaN   99118995          push
# 1     6994                  NaN   99100662          push
# 2     6993                  NaN   99093472          push
# 3     6992                  NaN   99086186          push
# 4     6991                  NaN   99078711          push
# ..     ...                  ...        ...           ...
# 126  12162               1121.0  148002763  pull_request
# 127  12163                  NaN  148005346          push
# 128  12164               1121.0  148005355  pull_request
# 129  12165               1121.0  148010751  pull_request
# 130  12166                  NaN  148010754          push
#
#               finished_at                  pull_request_title  \
# 0    2015-12-28T16:34:08Z                                None
# 1    2015-12-28T14:36:03Z                                None
# 2    2015-12-28T13:27:51Z                                None
# 3    2015-12-28T12:18:41Z                                None
# 4    2015-12-28T10:56:34Z                                None
# ..                    ...                                 ...
# 126  2016-07-28T11:22:06Z  Provide WS to manage project links
# 127  2016-07-28T11:33:17Z                                None
# 128  2016-07-28T11:34:11Z  Provide WS to manage project links
# 129  2016-07-28T12:02:21Z  Provide WS to manage project links
# 130  2016-07-28T12:01:12Z                                None
#
#                started_at  duration   state
# 0    2015-12-28T16:18:41Z    5361.0  failed
# 1    2015-12-28T14:18:30Z    5953.0  passed
# 2    2015-12-28T13:11:39Z    5166.0  passed
# 3    2015-12-28T12:10:56Z    5243.0  passed
# 4    2015-12-28T10:41:16Z    5045.0  passed
# ..                    ...       ...     ...
# 126  2016-07-28T10:59:31Z    1431.0  passed
# 127  2016-07-28T11:13:59Z    1232.0  passed
# 128  2016-07-28T11:14:09Z    1279.0  passed
# 129  2016-07-28T11:41:56Z    1338.0  passed
# 130  2016-07-28T11:41:56Z    1239.0  passed
#
# [39514 rows x 9 columns]

# %%
allBuilds["number"] = pd.to_numeric(allBuilds.number)

# %%
allBuilds.number.max() == len(allBuilds.number.unique())
# Out:
# True

# %%
allBuilds
# Out:
#      number  pull_request_number         id    event_type  \
# 0      6995                  NaN   99118995          push
# 1      6994                  NaN   99100662          push
# 2      6993                  NaN   99093472          push
# 3      6992                  NaN   99086186          push
# 4      6991                  NaN   99078711          push
# ..      ...                  ...        ...           ...
# 126   12162               1121.0  148002763  pull_request
# 127   12163                  NaN  148005346          push
# 128   12164               1121.0  148005355  pull_request
# 129   12165               1121.0  148010751  pull_request
# 130   12166                  NaN  148010754          push
#
#               finished_at                  pull_request_title  \
# 0    2015-12-28T16:34:08Z                                None
# 1    2015-12-28T14:36:03Z                                None
# 2    2015-12-28T13:27:51Z                                None
# 3    2015-12-28T12:18:41Z                                None
# 4    2015-12-28T10:56:34Z                                None
# ..                    ...                                 ...
# 126  2016-07-28T11:22:06Z  Provide WS to manage project links
# 127  2016-07-28T11:33:17Z                                None
# 128  2016-07-28T11:34:11Z  Provide WS to manage project links
# 129  2016-07-28T12:02:21Z  Provide WS to manage project links
# 130  2016-07-28T12:01:12Z                                None
#
#                started_at  duration   state
# 0    2015-12-28T16:18:41Z    5361.0  failed
# 1    2015-12-28T14:18:30Z    5953.0  passed
# 2    2015-12-28T13:11:39Z    5166.0  passed
# 3    2015-12-28T12:10:56Z    5243.0  passed
# 4    2015-12-28T10:41:16Z    5045.0  passed
# ..                    ...       ...     ...
# 126  2016-07-28T10:59:31Z    1431.0  passed
# 127  2016-07-28T11:13:59Z    1232.0  passed
# 128  2016-07-28T11:14:09Z    1279.0  passed
# 129  2016-07-28T11:41:56Z    1338.0  passed
# 130  2016-07-28T11:41:56Z    1239.0  passed
#
# [39514 rows x 9 columns]

# %%
#allBuilds.to_csv("csv/allBuilds.csv")
allBuilds = pd.read_csv("csv/allBuilds.csv", index_col=0)
allBuilds
# Out:
#      number  pull_request_number         id    event_type  \
# 0      6995                  NaN   99118995          push
# 1      6994                  NaN   99100662          push
# 2      6993                  NaN   99093472          push
# 3      6992                  NaN   99086186          push
# 4      6991                  NaN   99078711          push
# ..      ...                  ...        ...           ...
# 126   12162               1121.0  148002763  pull_request
# 127   12163                  NaN  148005346          push
# 128   12164               1121.0  148005355  pull_request
# 129   12165               1121.0  148010751  pull_request
# 130   12166                  NaN  148010754          push
#
#               finished_at                  pull_request_title  \
# 0    2015-12-28T16:34:08Z                                 NaN
# 1    2015-12-28T14:36:03Z                                 NaN
# 2    2015-12-28T13:27:51Z                                 NaN
# 3    2015-12-28T12:18:41Z                                 NaN
# 4    2015-12-28T10:56:34Z                                 NaN
# ..                    ...                                 ...
# 126  2016-07-28T11:22:06Z  Provide WS to manage project links
# 127  2016-07-28T11:33:17Z                                 NaN
# 128  2016-07-28T11:34:11Z  Provide WS to manage project links
# 129  2016-07-28T12:02:21Z  Provide WS to manage project links
# 130  2016-07-28T12:01:12Z                                 NaN
#
#                started_at  duration   state
# 0    2015-12-28T16:18:41Z    5361.0  failed
# 1    2015-12-28T14:18:30Z    5953.0  passed
# 2    2015-12-28T13:11:39Z    5166.0  passed
# 3    2015-12-28T12:10:56Z    5243.0  passed
# 4    2015-12-28T10:41:16Z    5045.0  passed
# ..                    ...       ...     ...
# 126  2016-07-28T10:59:31Z    1431.0  passed
# 127  2016-07-28T11:13:59Z    1232.0  passed
# 128  2016-07-28T11:14:09Z    1279.0  passed
# 129  2016-07-28T11:41:56Z    1338.0  passed
# 130  2016-07-28T11:41:56Z    1239.0  passed
#
# [39514 rows x 9 columns]

# %% [markdown]
# ## Jobs

# %%
job_tuples = []

# %%
for v2_file in v2_files:
    with open(v2_file, 'rb') as f:
        builds2 = pickle.load(f)
        for build in builds2:
            build_values = []
            for job in build["job_ids"]:
                job_tuples.append((build["id"], build["number"], job))

# %%
for v3_file in v3_files:
    with open(v3_file, 'rb') as f:
        builds3 = pickle.load(f)
        for build in builds3:
            build_values = []
            for job in build["jobs"]:
                job_tuples.append((build["id"], build["number"], job["id"]))

# %%
with open("builds/all_missing_builds.pkl", 'rb') as f:
    builds2 = pickle.load(f)
    for build in builds2:
        build_values = []
        for job in build["job_ids"]:
            job_tuples.append((build["id"], build["number"], job))

# %%
jobsDf = pd.DataFrame(job_tuples, columns = ["build_id", "build_number", "job_id"])
jobsDf.to_csv("csv/job_id_build_id.csv")
jobsDf
# Out:
#          build_id build_number     job_id
# 0        99118995         6995   99118996
# 1        99118995         6995   99118997
# 2        99118995         6995   99118998
# 3        99118995         6995   99118999
# 4        99118995         6995   99119000
# ...           ...          ...        ...
# 136978  148005355        12164  148005357
# 136979  148010751        12165  148010752
# 136980  148010751        12165  148010753
# 136981  148010754        12166  148010755
# 136982  148010754        12166  148010756
#
# [136983 rows x 3 columns]

# %%
jobsDf.build_number = pd.to_numeric(jobsDf.build_number)

# %% [markdown]
# **Do we have all builds for all jobs in RTPTorrent?**

# %%
len(set(jobIds)-(set(jobsDf.job_id.unique())))
# Out:
# 0

# %% [markdown]
# ### Compare our dataset to TravisTorrent

# %% [markdown]
# **Number of builds up until the latest in TravisTorrent**

# %% [markdown]
# TravisTorrent

# %%
travis_builds = len(project_df.tr_build_number.unique())

# %% [markdown]
# Our dataset

# %%
ours_builds = len(allBuilds[allBuilds.number < project_df.tr_build_number.max()])

# %%
ax = sns.barplot(x="Builds", y="Dataset",
            data=pd.DataFrame([("TravisTorrent", travis_builds),("Ours", ours_builds)],columns=["Dataset", "Builds"]))
ax.set_title(f"Counted up until latest build in TravisTorrent ({project_df.tr_build_number.max()})")
# Out:
# Text(0.5, 1.0, 'Counted up until latest build in TravisTorrent (12912)')

# %%
missing_build_numbers = []
build_numbers = allBuilds.number.unique()
for i in range(0, project_df.tr_build_number.max()):
    if i not in build_numbers:
        missing_build_numbers.append(i)
sns.distplot(missing_build_numbers)
plt.axvline(max_build_number, 0, 10, color="r")
# Out:
# /Users/alexincerti/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **TravisTorrent has 1 job_id per row**

# %%
len(project_df) == len(project_df.tr_job_id.unique())
# Out:
# True

# %% [markdown]
# **Number of job ids up until the last build number in TraviTorrent**

# %% [markdown]
# TravisTorrent

# %%
travis_jobs = len(project_df.tr_job_id.unique())

# %% [markdown]
# Our dataset

# %%
ids = list(allBuilds[allBuilds.number < project_df.tr_build_number.max()].id)
ours_jobs = len(jobsDf[jobsDf.build_id.isin(ids)])

# %%
ax = sns.barplot(x="Jobs", y="Dataset",
            data=pd.DataFrame([("TravisTorrent", travis_jobs),("Ours", ours_jobs)],columns=["Dataset", "Jobs"]))
ax.set_title(f"Counted up until latest build in TravisTorrent ({project_df.tr_build_number.max()})")
# Out:
# Text(0.5, 1.0, 'Counted up until latest build in TravisTorrent (12912)')

# %%
pd.DataFrame([("TravisTorrent", travis_jobs),("Ours", ours_jobs)],columns=["Dataset", "Jobs"])
# Out:
#          Dataset   Jobs
# 0  TravisTorrent  30142
# 1           Ours  85003

# %%
group_size = 400
t = jobsDf.groupby("build_number").count().reset_index()
t["groups"] = t.build_number.apply(lambda x: int(x / group_size))
data=t.groupby("groups").mean().reset_index()
ax = sns.barplot(x="groups",y="job_id",data=data)
ax.tick_params(axis='x', labelrotation= 45)

ax.set_title("Avarage number of jobs per build over time")
ax.set_xlabel("build grouped in 400")
ax.set_ylabel("Average number of jobs")

plt.axvline(int(project_df.tr_build_number.max()/group_size), 0, 10, color="r")

# %% [markdown]
# ### Look at a couple of builds not included in TravisTorrent

# %%
notinTravis = allBuilds[allBuilds.id.isin(set(allBuilds[allBuilds.number < project_df.tr_build_number.max()].id) - set(project_df.tr_build_id))]

# %%
notinTravis.sort_values(by="number").head(10)
# Out:
#       number  pull_request_number        id    event_type  \
# 9986       9                  NaN  54834266          push
# 9985      10                149.0  54834270  pull_request
# 9980      15                  NaN  54846160          push
# 9979      16                149.0  54846165  pull_request
# 9978      17                  NaN  54851644          push
# 9977      18                149.0  54851656  pull_request
# 9961      34                  NaN  54890670          push
# 9954      41                  NaN  55001342          push
# 9953      42                  NaN  55004381          push
# 9952      43                150.0  55004384  pull_request
#
#                finished_at                                 pull_request_title  \
# 9986  2015-03-18T08:21:19Z                                               None
# 9985  2015-03-18T08:21:17Z  SONAR-6236 Migrate existing dashboards to use ...
# 9980  2015-03-18T10:18:56Z                                               None
# 9979  2015-03-18T10:18:50Z  SONAR-6236 Migrate existing dashboards to use ...
# 9978  2015-03-18T11:00:47Z                                               None
# 9977  2015-03-18T11:01:34Z  SONAR-6236 Migrate existing dashboards to use ...
# 9961  2015-03-18T16:03:59Z                                               None
# 9954  2015-03-19T10:21:10Z                                               None
# 9953  2015-03-19T10:49:22Z                                               None
# 9952  2015-03-19T10:48:36Z  Move measures persistence from batch to comput...
#
#                 started_at  duration   state
# 9986  2015-03-18T08:18:56Z     242.0  failed
# 9985  2015-03-18T08:18:57Z     232.0  failed
# 9980  2015-03-18T10:16:32Z     260.0  failed
# 9979  2015-03-18T10:16:40Z     252.0  failed
# 9978  2015-03-18T10:58:54Z     220.0  failed
# 9977  2015-03-18T10:58:54Z     261.0  failed
# 9961  2015-03-18T15:58:20Z     423.0  failed
# 9954  2015-03-19T10:19:05Z     218.0  failed
# 9953  2015-03-19T10:46:38Z     268.0  failed
# 9952  2015-03-19T10:46:38Z     213.0  failed

# %%
sns.countplot(notinTravis.state)
# Out:
# <AxesSubplot:xlabel='state', ylabel='count'>

# %%
sns.countplot(notinTravis.event_type)
# Out:
# <AxesSubplot:xlabel='event_type', ylabel='count'>

# %%
jobsDf.sort_values(by="build_number")
# Out:
#          build_id  build_number     job_id
# 69117    54731125             1   54731127
# 69116    54731125             1   54731126
# 69115    54734500             2   54734502
# 69114    54734500             2   54734501
# 69113    54738299             3   54738301
# ...           ...           ...        ...
# 126974  730062832         39425  730062833
# 126973  731079493         39426  731079495
# 126972  731079493         39426  731079494
# 126971  731395956         39427  731395958
# 126970  731395956         39427  731395957
#
# [136983 rows x 3 columns]

# %% [markdown]
# pp = pprint.PrettyPrinter(depth=6)
# current_jobs = []
# i = 0
# offset=24700
# failed = 0
# for build_id in allBuilds.sort_values(by="id").id.unique():
#     if i < offset:
#         i+=1
#         continue
#     jobs = travis.get_jobs(build_id)
#     if not jobs:
#         print(f"Failed build {build_id}")
#         failed+=1
#     else:
#         current_jobs = current_jobs + jobs
#         i+=1
#     if(i % 100 == 0):
#         print(f"Downloaded jobs: {i}...")
#         with open(f'jobs/jobs{i}.pkl', 'wb') as f:
#             pickle.dump(current_jobs, f)
#         current_jobs = []
# print(i)
