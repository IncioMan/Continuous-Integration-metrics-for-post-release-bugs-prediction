# %%
import pickle
import pprint
import glob
import pandas as pd
import seaborn as sns
pp = pprint.PrettyPrinter(depth=6)
pd.set_option('max_colwidth',400)

# %%
csv_folder = "../csv"
folder = "../pull_requests"

# %% [markdown]
# ### Import df

# %%
jobsDf = pd.read_csv(f"{csv_folder}/allJobs.csv", index_col=0)

# %%
sha_tag1_tag2 = ['d32824d330ea631ce90a1d4de94836569ab898f9',
 '32e0abb294c2fbfadb7789f575b9d8e0d098d300',
 'c6bfd5186b41d3005f425c564fed7621e6d834b5',
 '2acee04f1c45fc78130ca31431de294484e45d3d',
 '0c7ce63bfe52e0c540637b3bb864caa1b54c8878',
 '5eb66cb787b5dad7f748a64e7e14c41c6a13cd6e',
 'f0b347e2f6f8fd53126c1a040b72a85a4defe4b1',
 '5d01496570c512ac96c1503f3db68dad1ff2927c',
 'e70058e93a5c570e836b9276f63441888907eaf1',
 '257fe4bcb4fe30d7afdd4f05f2838ca40c08314f',
 '3b8a208d1270f9dc7f8272fa10f72007cde16654',
 'ef34d6ad5094cb0a7910b4d91bec6324621d8214',
 'f90e07c2758222d8756c5d22d1e48a6cd1c4b8ea',
 '03d48e10b34f3c3efb396d0fd64e85f7c1adfbde',
 '9e0049ae28caf5ee6998af450404e23f34a0ef47',
 'a22748242b5b290b9ee978b451736512a89db761',
 '0e9caf0c013529f14d4e22561c38f050165c6772',
 '4231794af086f18afc7f6d6f56a157988597c8b3',
 '77e0d76f18ee2429ad7fe244e2a0930743617a8d',
 '66286b52fc378abc2015f7a5eba4d040d02d6d94',
 '8a667b2e3358144ea6d0affaf7673ebd290b0b78']

# %%
pr_files = glob.glob(f"{folder}/*.pkl")
prs_raw = []
for pr_file in pr_files:
    with open(pr_file, "rb") as f:
        prs_raw = prs_raw + pickle.load(f)

# %%
pp.pprint(prs_raw[0][0])
# Out:
# {'_links': {'comments': {'href': 'https://api.github.com/repos/SonarSource/sonarqube/issues/2016/comments'},
#             'commits': {'href': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/2016/commits'},
#             'html': {'href': 'https://github.com/SonarSource/sonarqube/pull/2016'},
#             'issue': {'href': 'https://api.github.com/repos/SonarSource/sonarqube/issues/2016'},
#             'review_comment': {'href': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/comments{/number}'},
#             'review_comments': {'href': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/2016/comments'},
#             'self': {'href': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/2016'},
#             'statuses': {'href': 'https://api.github.com/repos/SonarSource/sonarqube/statuses/66dcca6c302a3af95f5b7d3ca269588680bf8a82'}},
#  'active_lock_reason': None,
#  'additions': 1,
#  'assignee': None,
#  'assignees': [],
#  'author_association': 'NONE',
#  'base': {'label': 'SonarSource:master',
#           'ref': 'master',
#           'repo': {'archive_url': 'https://api.github.com/repos/SonarSource/sonarqube/{archive_format}{/ref}',
#                    'archived': False,
#                    'assignees_url': 'https://api.github.com/repos/SonarSource/sonarqube/assignees{/user}',
#                    'blobs_url': 'https://api.github.com/repos/SonarSource/sonarqube/git/blobs{/sha}',
#                    'branches_url': 'https://api.github.com/repos/SonarSource/sonarqube/branches{/branch}',
#                    'clone_url': 'https://github.com/SonarSource/sonarqube.git',
#                    'collaborators_url': 'https://api.github.com/repos/SonarSource/sonarqube/collaborators{/collaborator}',
#                    'comments_url': 'https://api.github.com/repos/SonarSource/sonarqube/comments{/number}',
#                    'commits_url': 'https://api.github.com/repos/SonarSource/sonarqube/commits{/sha}',
#                    'compare_url': 'https://api.github.com/repos/SonarSource/sonarqube/compare/{base}...{head}',
#                    'contents_url': 'https://api.github.com/repos/SonarSource/sonarqube/contents/{+path}',
#                    'contributors_url': 'https://api.github.com/repos/SonarSource/sonarqube/contributors',
#                    'created_at': '2011-01-05T11:05:17Z',
#                    'default_branch': 'master',
#                    'deployments_url': 'https://api.github.com/repos/SonarSource/sonarqube/deployments',
#                    'description': 'Continuous Inspection',
#                    'disabled': False,
#                    'downloads_url': 'https://api.github.com/repos/SonarSource/sonarqube/downloads',
#                    'events_url': 'https://api.github.com/repos/SonarSource/sonarqube/events',
#                    'fork': False,
#                    'forks': 1346,
#                    'forks_count': 1346,
#                    'forks_url': 'https://api.github.com/repos/SonarSource/sonarqube/forks',
#                    'full_name': 'SonarSource/sonarqube',
#                    'git_commits_url': 'https://api.github.com/repos/SonarSource/sonarqube/git/commits{/sha}',
#                    'git_refs_url': 'https://api.github.com/repos/SonarSource/sonarqube/git/refs{/sha}',
#                    'git_tags_url': 'https://api.github.com/repos/SonarSource/sonarqube/git/tags{/sha}',
#                    'git_url': 'git://github.com/SonarSource/sonarqube.git',
#                    'has_downloads': True,
#                    'has_issues': False,
#                    'has_pages': False,
#                    'has_projects': False,
#                    'has_wiki': False,
#                    'homepage': 'http://www.sonarqube.org',
#                    'hooks_url': 'https://api.github.com/repos/SonarSource/sonarqube/hooks',
#                    'html_url': 'https://github.com/SonarSource/sonarqube',
#                    'id': 1222504,
#                    'issue_comment_url': 'https://api.github.com/repos/SonarSource/sonarqube/issues/comments{/number}',
#                    'issue_events_url': 'https://api.github.com/repos/SonarSource/sonarqube/issues/events{/number}',
#                    'issues_url': 'https://api.github.com/repos/SonarSource/sonarqube/issues{/number}',
#                    'keys_url': 'https://api.github.com/repos/SonarSource/sonarqube/keys{/key_id}',
#                    'labels_url': 'https://api.github.com/repos/SonarSource/sonarqube/labels{/name}',
#                    'language': 'Java',
#                    'languages_url': 'https://api.github.com/repos/SonarSource/sonarqube/languages',
#                    'license': {'key': 'lgpl-3.0',
#                                'name': 'GNU Lesser General Public License v3.0',
#                                'node_id': 'MDc6TGljZW5zZTEy',
#                                'spdx_id': 'LGPL-3.0',
#                                'url': 'https://api.github.com/licenses/lgpl-3.0'},
#                    'merges_url': 'https://api.github.com/repos/SonarSource/sonarqube/merges',
#                    'milestones_url': 'https://api.github.com/repos/SonarSource/sonarqube/milestones{/number}',
#                    'mirror_url': None,
#                    'name': 'sonarqube',
#                    'node_id': 'MDEwOlJlcG9zaXRvcnkxMjIyNTA0',
#                    'notifications_url': 'https://api.github.com/repos/SonarSource/sonarqube/notifications{?since,all,participating}',
#                    'open_issues': 3,
#                    'open_issues_count': 3,
#                    'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/545988?v=4',
#                              'events_url': 'https://api.github.com/users/SonarSource/events{/privacy}',
#                              'followers_url': 'https://api.github.com/users/SonarSource/followers',
#                              'following_url': 'https://api.github.com/users/SonarSource/following{/other_user}',
#                              'gists_url': 'https://api.github.com/users/SonarSource/gists{/gist_id}',
#                              'gravatar_id': '',
#                              'html_url': 'https://github.com/SonarSource',
#                              'id': 545988,
#                              'login': 'SonarSource',
#                              'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0NTk4OA==',
#                              'organizations_url': 'https://api.github.com/users/SonarSource/orgs',
#                              'received_events_url': 'https://api.github.com/users/SonarSource/received_events',
#                              'repos_url': 'https://api.github.com/users/SonarSource/repos',
#                              'site_admin': False,
#                              'starred_url': 'https://api.github.com/users/SonarSource/starred{/owner}{/repo}',
#                              'subscriptions_url': 'https://api.github.com/users/SonarSource/subscriptions',
#                              'type': 'Organization',
#                              'url': 'https://api.github.com/users/SonarSource'},
#                    'private': False,
#                    'pulls_url': 'https://api.github.com/repos/SonarSource/sonarqube/pulls{/number}',
#                    'pushed_at': '2020-10-02T20:08:04Z',
#                    'releases_url': 'https://api.github.com/repos/SonarSource/sonarqube/releases{/id}',
#                    'size': 540474,
#                    'ssh_url': 'git@github.com:SonarSource/sonarqube.git',
#                    'stargazers_count': 5153,
#                    'stargazers_url': 'https://api.github.com/repos/SonarSource/sonarqube/stargazers',
#                    'statuses_url': 'https://api.github.com/repos/SonarSource/sonarqube/statuses/{sha}',
#                    'subscribers_url': 'https://api.github.com/repos/SonarSource/sonarqube/subscribers',
#                    'subscription_url': 'https://api.github.com/repos/SonarSource/sonarqube/subscription',
#                    'svn_url': 'https://github.com/SonarSource/sonarqube',
#                    'tags_url': 'https://api.github.com/repos/SonarSource/sonarqube/tags',
#                    'teams_url': 'https://api.github.com/repos/SonarSource/sonarqube/teams',
#                    'trees_url': 'https://api.github.com/repos/SonarSource/sonarqube/git/trees{/sha}',
#                    'updated_at': '2020-10-05T08:28:05Z',
#                    'url': 'https://api.github.com/repos/SonarSource/sonarqube',
#                    'watchers': 5153,
#                    'watchers_count': 5153},
#           'sha': 'b10cb50ec7c26a85dd549de6633e60705994bd66',
#           'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/545988?v=4',
#                    'events_url': 'https://api.github.com/users/SonarSource/events{/privacy}',
#                    'followers_url': 'https://api.github.com/users/SonarSource/followers',
#                    'following_url': 'https://api.github.com/users/SonarSource/following{/other_user}',
#                    'gists_url': 'https://api.github.com/users/SonarSource/gists{/gist_id}',
#                    'gravatar_id': '',
#                    'html_url': 'https://github.com/SonarSource',
#                    'id': 545988,
#                    'login': 'SonarSource',
#                    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0NTk4OA==',
#                    'organizations_url': 'https://api.github.com/users/SonarSource/orgs',
#                    'received_events_url': 'https://api.github.com/users/SonarSource/received_events',
#                    'repos_url': 'https://api.github.com/users/SonarSource/repos',
#                    'site_admin': False,
#                    'starred_url': 'https://api.github.com/users/SonarSource/starred{/owner}{/repo}',
#                    'subscriptions_url': 'https://api.github.com/users/SonarSource/subscriptions',
#                    'type': 'Organization',
#                    'url': 'https://api.github.com/users/SonarSource'}},
#  'body': 'When new users initialise their SonarQube instance, it would be '
#          'better to \r\n'
#          "make their system to follow the 'secure-by-default' mantra. \r\n"
#          '\r\n'
#          'The current configuration of `sonar.forceAuthentication = false` '
#          'means that \r\n'
#          'as soon as a SonarQube instance is hosted and has scanned a project, '
#          'there is \r\n'
#          'potentially sensitive information exposed to non-authenticated users '
#          'that could\r\n'
#          'just connect to the server.\r\n'
#          '\r\n'
#          'While this is not an issue for more experienced users, for those '
#          'less-knowledgeable, \r\n'
#          'it can expose them to an unnecessary vulnerability.\r\n'
#          '\r\n'
#          "P.S. I searched here and in JIRA for related issues/PRs and couldn't "
#          "find anything. I also tried to raise an issue on JIRA but didn't "
#          'have permission to submit one. Thought the easiest way would be to '
#          'put a PR in for discussion/merging. Thanks!',
#  'changed_files': 1,
#  'closed_at': '2017-05-10T10:09:34Z',
#  'comments': 0,
#  'comments_url': 'https://api.github.com/repos/SonarSource/sonarqube/issues/2016/comments',
#  'commits': 1,
#  'commits_url': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/2016/commits',
#  'created_at': '2017-05-03T13:08:47Z',
#  'deletions': 1,
#  'diff_url': 'https://github.com/SonarSource/sonarqube/pull/2016.diff',
#  'draft': False,
#  'head': {'label': 'allyjweir:feature/enable-authentication-by-default',
#           'ref': 'feature/enable-authentication-by-default',
#           'repo': {'archive_url': 'https://api.github.com/repos/allyjweir/sonarqube/{archive_format}{/ref}',
#                    'archived': False,
#                    'assignees_url': 'https://api.github.com/repos/allyjweir/sonarqube/assignees{/user}',
#                    'blobs_url': 'https://api.github.com/repos/allyjweir/sonarqube/git/blobs{/sha}',
#                    'branches_url': 'https://api.github.com/repos/allyjweir/sonarqube/branches{/branch}',
#                    'clone_url': 'https://github.com/allyjweir/sonarqube.git',
#                    'collaborators_url': 'https://api.github.com/repos/allyjweir/sonarqube/collaborators{/collaborator}',
#                    'comments_url': 'https://api.github.com/repos/allyjweir/sonarqube/comments{/number}',
#                    'commits_url': 'https://api.github.com/repos/allyjweir/sonarqube/commits{/sha}',
#                    'compare_url': 'https://api.github.com/repos/allyjweir/sonarqube/compare/{base}...{head}',
#                    'contents_url': 'https://api.github.com/repos/allyjweir/sonarqube/contents/{+path}',
#                    'contributors_url': 'https://api.github.com/repos/allyjweir/sonarqube/contributors',
#                    'created_at': '2017-05-03T12:55:00Z',
#                    'default_branch': 'master',
#                    'deployments_url': 'https://api.github.com/repos/allyjweir/sonarqube/deployments',
#                    'description': 'Continuous Code Quality',
#                    'disabled': False,
#                    'downloads_url': 'https://api.github.com/repos/allyjweir/sonarqube/downloads',
#                    'events_url': 'https://api.github.com/repos/allyjweir/sonarqube/events',
#                    'fork': True,
#                    'forks': 0,
#                    'forks_count': 0,
#                    'forks_url': 'https://api.github.com/repos/allyjweir/sonarqube/forks',
#                    'full_name': 'allyjweir/sonarqube',
#                    'git_commits_url': 'https://api.github.com/repos/allyjweir/sonarqube/git/commits{/sha}',
#                    'git_refs_url': 'https://api.github.com/repos/allyjweir/sonarqube/git/refs{/sha}',
#                    'git_tags_url': 'https://api.github.com/repos/allyjweir/sonarqube/git/tags{/sha}',
#                    'git_url': 'git://github.com/allyjweir/sonarqube.git',
#                    'has_downloads': True,
#                    'has_issues': False,
#                    'has_pages': False,
#                    'has_projects': True,
#                    'has_wiki': False,
#                    'homepage': 'http://www.sonarqube.org',
#                    'hooks_url': 'https://api.github.com/repos/allyjweir/sonarqube/hooks',
#                    'html_url': 'https://github.com/allyjweir/sonarqube',
#                    'id': 90148912,
#                    'issue_comment_url': 'https://api.github.com/repos/allyjweir/sonarqube/issues/comments{/number}',
#                    'issue_events_url': 'https://api.github.com/repos/allyjweir/sonarqube/issues/events{/number}',
#                    'issues_url': 'https://api.github.com/repos/allyjweir/sonarqube/issues{/number}',
#                    'keys_url': 'https://api.github.com/repos/allyjweir/sonarqube/keys{/key_id}',
#                    'labels_url': 'https://api.github.com/repos/allyjweir/sonarqube/labels{/name}',
#                    'language': 'Java',
#                    'languages_url': 'https://api.github.com/repos/allyjweir/sonarqube/languages',
#                    'license': {'key': 'other',
#                                'name': 'Other',
#                                'node_id': 'MDc6TGljZW5zZTA=',
#                                'spdx_id': 'NOASSERTION',
#                                'url': None},
#                    'merges_url': 'https://api.github.com/repos/allyjweir/sonarqube/merges',
#                    'milestones_url': 'https://api.github.com/repos/allyjweir/sonarqube/milestones{/number}',
#                    'mirror_url': None,
#                    'name': 'sonarqube',
#                    'node_id': 'MDEwOlJlcG9zaXRvcnk5MDE0ODkxMg==',
#                    'notifications_url': 'https://api.github.com/repos/allyjweir/sonarqube/notifications{?since,all,participating}',
#                    'open_issues': 0,
#                    'open_issues_count': 0,
#                    'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/3640069?v=4',
#                              'events_url': 'https://api.github.com/users/allyjweir/events{/privacy}',
#                              'followers_url': 'https://api.github.com/users/allyjweir/followers',
#                              'following_url': 'https://api.github.com/users/allyjweir/following{/other_user}',
#                              'gists_url': 'https://api.github.com/users/allyjweir/gists{/gist_id}',
#                              'gravatar_id': '',
#                              'html_url': 'https://github.com/allyjweir',
#                              'id': 3640069,
#                              'login': 'allyjweir',
#                              'node_id': 'MDQ6VXNlcjM2NDAwNjk=',
#                              'organizations_url': 'https://api.github.com/users/allyjweir/orgs',
#                              'received_events_url': 'https://api.github.com/users/allyjweir/received_events',
#                              'repos_url': 'https://api.github.com/users/allyjweir/repos',
#                              'site_admin': False,
#                              'starred_url': 'https://api.github.com/users/allyjweir/starred{/owner}{/repo}',
#                              'subscriptions_url': 'https://api.github.com/users/allyjweir/subscriptions',
#                              'type': 'User',
#                              'url': 'https://api.github.com/users/allyjweir'},
#                    'private': False,
#                    'pulls_url': 'https://api.github.com/repos/allyjweir/sonarqube/pulls{/number}',
#                    'pushed_at': '2017-05-03T13:08:09Z',
#                    'releases_url': 'https://api.github.com/repos/allyjweir/sonarqube/releases{/id}',
#                    'size': 160703,
#                    'ssh_url': 'git@github.com:allyjweir/sonarqube.git',
#                    'stargazers_count': 0,
#                    'stargazers_url': 'https://api.github.com/repos/allyjweir/sonarqube/stargazers',
#                    'statuses_url': 'https://api.github.com/repos/allyjweir/sonarqube/statuses/{sha}',
#                    'subscribers_url': 'https://api.github.com/repos/allyjweir/sonarqube/subscribers',
#                    'subscription_url': 'https://api.github.com/repos/allyjweir/sonarqube/subscription',
#                    'svn_url': 'https://github.com/allyjweir/sonarqube',
#                    'tags_url': 'https://api.github.com/repos/allyjweir/sonarqube/tags',
#                    'teams_url': 'https://api.github.com/repos/allyjweir/sonarqube/teams',
#                    'trees_url': 'https://api.github.com/repos/allyjweir/sonarqube/git/trees{/sha}',
#                    'updated_at': '2017-05-03T12:55:26Z',
#                    'url': 'https://api.github.com/repos/allyjweir/sonarqube',
#                    'watchers': 0,
#                    'watchers_count': 0},
#           'sha': '66dcca6c302a3af95f5b7d3ca269588680bf8a82',
#           'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/3640069?v=4',
#                    'events_url': 'https://api.github.com/users/allyjweir/events{/privacy}',
#                    'followers_url': 'https://api.github.com/users/allyjweir/followers',
#                    'following_url': 'https://api.github.com/users/allyjweir/following{/other_user}',
#                    'gists_url': 'https://api.github.com/users/allyjweir/gists{/gist_id}',
#                    'gravatar_id': '',
#                    'html_url': 'https://github.com/allyjweir',
#                    'id': 3640069,
#                    'login': 'allyjweir',
#                    'node_id': 'MDQ6VXNlcjM2NDAwNjk=',
#                    'organizations_url': 'https://api.github.com/users/allyjweir/orgs',
#                    'received_events_url': 'https://api.github.com/users/allyjweir/received_events',
#                    'repos_url': 'https://api.github.com/users/allyjweir/repos',
#                    'site_admin': False,
#                    'starred_url': 'https://api.github.com/users/allyjweir/starred{/owner}{/repo}',
#                    'subscriptions_url': 'https://api.github.com/users/allyjweir/subscriptions',
#                    'type': 'User',
#                    'url': 'https://api.github.com/users/allyjweir'}},
#  'html_url': 'https://github.com/SonarSource/sonarqube/pull/2016',
#  'id': 118757181,
#  'issue_url': 'https://api.github.com/repos/SonarSource/sonarqube/issues/2016',
#  'labels': [],
#  'locked': False,
#  'maintainer_can_modify': False,
#  'merge_commit_sha': 'bd681aa308db8e4b0b202f745d323b30182e1dd7',
#  'mergeable': None,
#  'mergeable_state': 'unknown',
#  'merged': False,
#  'merged_at': None,
#  'merged_by': None,
#  'milestone': None,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0MTE4NzU3MTgx',
#  'number': 2016,
#  'patch_url': 'https://github.com/SonarSource/sonarqube/pull/2016.patch',
#  'rebaseable': None,
#  'requested_reviewers': [],
#  'requested_teams': [],
#  'review_comment_url': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/comments{/number}',
#  'review_comments': 0,
#  'review_comments_url': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/2016/comments',
#  'state': 'closed',
#  'statuses_url': 'https://api.github.com/repos/SonarSource/sonarqube/statuses/66dcca6c302a3af95f5b7d3ca269588680bf8a82',
#  'title': 'Force authentication by default',
#  'updated_at': '2017-05-10T10:09:34Z',
#  'url': 'https://api.github.com/repos/SonarSource/sonarqube/pulls/2016',
#  'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/3640069?v=4',
#           'events_url': 'https://api.github.com/users/allyjweir/events{/privacy}',
#           'followers_url': 'https://api.github.com/users/allyjweir/followers',
#           'following_url': 'https://api.github.com/users/allyjweir/following{/other_user}',
#           'gists_url': 'https://api.github.com/users/allyjweir/gists{/gist_id}',
#           'gravatar_id': '',
#           'html_url': 'https://github.com/allyjweir',
#           'id': 3640069,
#           'login': 'allyjweir',
#           'node_id': 'MDQ6VXNlcjM2NDAwNjk=',
#           'organizations_url': 'https://api.github.com/users/allyjweir/orgs',
#           'received_events_url': 'https://api.github.com/users/allyjweir/received_events',
#           'repos_url': 'https://api.github.com/users/allyjweir/repos',
#           'site_admin': False,
#           'starred_url': 'https://api.github.com/users/allyjweir/starred{/owner}{/repo}',
#           'subscriptions_url': 'https://api.github.com/users/allyjweir/subscriptions',
#           'type': 'User',
#           'url': 'https://api.github.com/users/allyjweir'}}

# %%
prs_commits_data = []
prs_data = []
for pr in prs_raw:
    if not "number" in pr[0]:
        continue
    prs_data.append((pr[0]["number"], pr[0]["title"], pr[0]["base"]["sha"], pr[0]["head"]["sha"]))
    for commit in pr[1]:
        prs_commits_data.append((pr[0]["number"], commit["sha"]))

# %%
pr_commits = pd.DataFrame(prs_commits_data, columns=["pr_number", "commitsha"])
pr_commits
# Out:
#        pr_number                                 commitsha
# 0           2016  66dcca6c302a3af95f5b7d3ca269588680bf8a82
# 1           2029  da3dff653d07655d6ebecb1d869f6bd93a8763c9
# 2           2029  c273e7ce2ac80d9f230f85b89f49e603b8d726ca
# 3           2029  0c9fca66dea0b8ab3825b0fe484188f07c5802e4
# 4           2029  5dfcbf4bd034c59b24b218dbe440c93346b99949
# ...          ...                                       ...
# 12363        616  52c69fcd007fcad58f23bc80ffcab9b06326fb0a
# 12364        602  8d809c371e9b00c1886b1f7e83d8699e546bdb0e
# 12365        621  347978968e87735dacb333f72e32f20b8a7a3163
# 12366        621  f1b4428c014da7768d14bbd34cc322594b283bb4
# 12367        621  ae7efa83ddab2008efab798ef9b8b119009aca69
#
# [12368 rows x 2 columns]

# %%
prs = pd.DataFrame(prs_data, columns=["pr_number", "title", "base_sha", "head_sha"])
prs
# Out:
#       pr_number  \
# 0          2016
# 1          2029
# 2          2028
# 3          2007
# 4          2046
# ...         ...
# 3203        628
# 3204        604
# 3205        616
# 3206        602
# 3207        621
#
#                                                                        title  \
# 0                                            Force authentication by default
# 1                                                     SQ 6.4 web hardening 6
# 2                                                         Fix quality issues
# 3     SONAR-8949 let api/rules/update permission check use the specified org
# 4                                                        Hardening Wednesday
# ...                                                                      ...
# 3203  Try to delete deprecated NoSonarFilter to see if some plugins still r…
# 3204            SONAR-6356 Use first analysis when no previous version exist
# 3205  SONAR-6658 Remove ProjectClasspath, ProjectFileSystem, sonar.binaries…
# 3206                    SONAR-6834 Purge CE_ACTIVITY when deleting a project
# 3207                                                  Feature/issue location
#
#                                       base_sha  \
# 0     b10cb50ec7c26a85dd549de6633e60705994bd66
# 1     87d60ccc748d84f55f7c102b6ec6d489215eef8f
# 2     788e9efeaf3284175b2d3e5079b9256d64239ac8
# 3     7b2958e443c4c629f3e35aba7182d7cb524b250b
# 4     7f939f50b63f7c6ac7aab6d8fbb71a06193df0be
# ...                                        ...
# 3203  2cd1a9722bf414d3ab9eb73a40bd138821a362e2
# 3204  5e41c3cb0a9eb5bd3099ee9cc337e7bc9938747f
# 3205  e2379a7ffa7e879ededf5f160f55eba26a785a6c
# 3206  19350f7eb06f0f46674ad394e0919edbae2b2a2a
# 3207  603295776739bbe6658786d2e677a3470fbd7544
#
#                                       head_sha
# 0     66dcca6c302a3af95f5b7d3ca269588680bf8a82
# 1     69301dcfbdb0ecaa14bd96f9da834cb89591a516
# 2     fc9cbe72d20a3ae56d07dfa90eb9bcbf6d70a269
# 3     95ab6e7618dfab70486606794dcac2cae28fb3f2
# 4     285e16edf389aa34db2bc2f0ce99a2e3042f3f32
# ...                                        ...
# 3203  1787a07549561cb576eeeeb31e2208b753d20cb3
# 3204  becbd7e7f511acb8b552692b16aa2edd8d785513
# 3205  52c69fcd007fcad58f23bc80ffcab9b06326fb0a
# 3206  8d809c371e9b00c1886b1f7e83d8699e546bdb0e
# 3207  ae7efa83ddab2008efab798ef9b8b119009aca69
#
# [3208 rows x 4 columns]

# %%
pr_commits.to_csv(f"{csv_folder}/pr_commits.csv")
prs.to_csv(f"{csv_folder}/prs.csv")

# %% [markdown]
# ### Pull requests between tag1 and tag2

# %%
prs_tags = prs[prs.head_sha.isin(sha_tag1_tag2) | prs.base_sha.isin(sha_tag1_tag2)]
num = prs_tags.pr_number
prs_tags
# Out:
#       pr_number  \
# 1262       1465
# 1294       1497
# 1297       1475
#
#                                                               title  \
# 1262                         SONAR-8416 authent event logs in 6.2.1
# 1294      Feature/sl/6.2/sonar 8416/causes with trailing upper case
# 1297  SONAR-8416 fix login failure log at OAuth2 successful authent
#
#                                       base_sha  \
# 1262  32e0abb294c2fbfadb7789f575b9d8e0d098d300
# 1294  4231794af086f18afc7f6d6f56a157988597c8b3
# 1297  a22748242b5b290b9ee978b451736512a89db761
#
#                                       head_sha
# 1262  a22748242b5b290b9ee978b451736512a89db761
# 1294  66286b52fc378abc2015f7a5eba4d040d02d6d94
# 1297  0e9caf0c013529f14d4e22561c38f050165c6772

# %%
jobsDf[jobsDf.commitsha.isin(pr_commits[pr_commits.pr_number.isin(num)].commitsha)].commitref.unique()
# Out:
# array(['refs/heads/feature/6.2/SONAR-8416/fix_login_failure_log_during_oauth2_authentication',
#        'refs/heads/branch-6.2',
#        'refs/heads/feature/sl/6.2/SONAR-8416/causes_with_trailing_upper_case',
#        'refs/heads/feature/sl/6.2/SONAR-8416/authent_event_logs_in_6.2.1'],
#       dtype=object)

# %%
pr_commits.groupby("pr_number").count().reset_index()\
[pr_commits.groupby("pr_number").count().reset_index().commitsha == 30].pr_number.unique()
# Out:
# array([  41,   43,   64,   69,   71,  113,  257,  370,  555,  795,  910,
#        1163, 1287, 1433, 1459, 1620, 1730, 1731, 1753, 1758, 1803, 1808,
#        1811, 1812, 1814, 1822, 1825, 1828, 1830, 1834, 1844, 1911, 1919,
#        1932, 1980, 2080, 2119, 2202, 2269, 2300, 2317, 2325, 2328, 2333,
#        2367, 2403, 2414, 2456, 2505, 2532, 2596, 2673, 2724, 2785, 2796,
#        2820, 2854, 2858, 2866, 2982, 2988, 3009, 3031, 3102, 3187, 3193,
#        3245])

# %%
pr_commits.pr_number.min()
# Out:
# 1

# %%
len(pr_commits.pr_number.unique())
# Out:
# 3147
